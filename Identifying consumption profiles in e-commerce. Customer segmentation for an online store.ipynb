# %% [markdown]
#  <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:#bdc3c7; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <h7 style="color:black; margin-bottom:20px"> Артём, привет!
#
# Мои комментарии и замечания далее по тексту помечены различными цветами:
#
# ---
# <div class="alert alert-block alert-danger">
# ⁉️ : Критическое замечание, которые следует исправить.
# </div>
#
# <div class="alert alert-block alert-warning">
# ✏️ : Рекомендация\совет на будущее.
# </div>
#
# <div class="alert alert-block alert-success">
# ✔️ : Когда всё сделано правильно.
# </div>
#
# ---
#
# Хорошей практикой является оставлять свои комментарии после исправлений замечаний или для вопросов, разъяснений. Для того чтобы мне было легче их найти, то выделяй, пожалуйста, с помощью цвета, например вот так:
#
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#
# Вопрос, который не останется незамеченным
#
# </div>
#
# ---
#
# **В рамках финального спринта у вас есть лимит на количество итераций проверок. Я буду для информативности их отмечать в итоговом ревью:**
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# **`[1/6]`**
#
# Итог ревью - ...
#
# </div>
#
# p.s.: не удаляй мои замечания, если предстоит что-то доработать в проекте.</h7>

# %% [markdown]
# ---
#
# <div id="1" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⚠️ ИТОГИ РЕВЬЮ ⚠️ : </b>
#
# **`[1/6]`**
#
# <s>В целом, проделана неплохая работа. Структура и логика проекта корректные. Исследовательский этап проведен на хорошем уровне, многие метрики рассчитаны правильно (но есть ошибки и путаница).
#
# Вопросы заказчика представлены, но необходимо доработать отдельные пункты. Радует, что проверка гипотез выполнена почти успешно.
#
# Я отметил критические моменты.
#
#
#
#  - [Ошибка №1](#div_id1)
#
#  - [Ошибка №2](#div_id2)
#
#  - [Ошибка №3](#div_id3)
#
#  - [Ошибка №4](#div_id4)
#
#  - [Ошибка №5](#div_id5)
#
#  - [Ошибка №6](#div_id6)
#
#  - [Ошибка №7](#div_id7)
#
#  - [Ошибка №8](#div_id8)
#
#  - [Ошибка №9](#div_id9)
#
#  - [Ошибка №10](#div_id10)
#
#  - [Ошибка №11](#div_id11)
#
# Посмотри, пожалуйста, мои замечания и рекомендации.
#
# </div>
#
# <div id="2" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⚠️ ИТОГИ РЕВЬЮ ⚠️ : </b>
#
# **`[2/6]`**
#
# <s>Привет. Спасибо за доработки, но остались еще моменты, которые требуют твоего внимания.
#
#
#
#  - [Ошибка №12](#div_id12)
#
#  - [Ошибка №13](#div_id13)
#
#  - [Ошибка №14](#div_id14)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Вместе с исправлениями добавил и презентацию - ссылку внизу в заключении

# %% [markdown]
# <div id="3" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⚠️ ИТОГИ РЕВЬЮ ⚠️ : </b>
#
# **`[3/6]`**
#
# Привет. Осталось разобраться с выбросами и смогу принять проект
#
#
#  - [Ошибка №15](#div_id15)
#
#  - [Ошибка №16](#div_id16)
#
#  - [Ошибка №17](#div_id17)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Расчет для выбросов изменил. Расчет и график для среднего чека для разных категорий убрал
#     - Презентацию изменил (слайды которые касались среднего чека)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> 🚀 ИТОГИ РЕВЬЮ 🚀 : </b>
#
# Привет! Проект полностью выполнен. Получилось хорошее исследование. Все важные моменты представлены.
#
# ---
#
# ![](https://media.giphy.com/media/xUKrrEnN9I5lnrcSMv/giphy-downsized-large.gif)
#
# ---
#
#
# Остался последний шаг - SQL!
#
# </div>
#
# ---

# %% [markdown]
# # Выявление профилей потребления в E-commerce: Сегментация покупателей интернет-магазина "Пока все ещё тут"

# %% [markdown]
# ## Введние и цели

# %% [markdown]
# Сегментация аудитории является ключевым инструментом в арсенале маркетологов и специалистов по аналитике данных, позволяя более точно адаптировать предложения под потребности и предпочтения различных групп потребителей. В условиях растущей конкуренции и высокой динамики развития e-commerce, персонализированные предложения становятся необходимым условием для привлечения и удержания клиентов. Правильная сегментация позволяет бизнесу предоставлять своим клиентам более персонализированные продукты, услуги или маркетинговые сообщения, что напрямую влияет на повышение конверсии. Это особенно важно в цифровом пространстве, где пользователи ожидают индивидуального подхода, а персонализированные предложения увеличивают их лояльность и частоту покупок.

# %% [markdown]
# Основная цель данного исследования — предоставить всесторонний анализ и рекомендации для повышения продаж и лояльности клиентов платформы «Пока всё ещё тут» через использование сегментированного маркетинга. Результатом нашего исследования станет готовая информационная платформа для создания таргетированных рекламных рассылок, которая поможет увеличить продажи, вернуть покупателей и улучшить ключевые бизнес-показатели. Этого мы достигнем, совершив следующие шаги:
#  - Проведем исследовательский анализ данных для выявления закономерностей в покупках клиентов.
#  - Определим сегменты покупателей на основе их истории покупок, ориентируясь на категории товаров.
#  - Сформулируем и проверим статистические гипотезы о различиях между выделенными сегментами.
#  - Разработаем рекомендации для:
#    - более эффективной маркетинговой стратегии. Исходя из анализа сегментов покупателей, разработаем рекомендации о том, каким клиентам и когда следует рассылать рекламные предложения о каких категориях товаров.
#    - стратегии увелечения продаж. Разработаем рекомендации по увеличению количества продаваемого товара для каждого сегмента.
#    - стратегию повышения лояльности. Предложим способы повышения "возвращаемости" покупателей для различных сегментов.

# %% [markdown]
# Для выполнения поставленных целей у нас в распоряжении есть датасет ecom_dataset_upd.csv, описывающий транзакции интернет-магазина товаров для дома и быта «Пока все ещё тут». Датасет включает следующие колонки:
# - date — дата заказа;
# - customer_id — идентификатор покупателя;
# - order_id — идентификатор заказа;
# - product — наименование товара;
# - quantity — количество товара в заказе;
# - price — цена товара.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида : </b>
#
# Очень хорошо, что представлено описание работы и данных, обозначены цели исследования. Так будет сразу понятно о чем проект.
#
# </div>

# %% [markdown]
# Перед началом исселовадния импортируем библиотеки и создадим функции, которые будем использовать в проекте.

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

import re
import pymorphy2

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from statsmodels.stats.multitest import multipletests
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def primary_analysis(df):

    display("Информация о датафрейме:")
    display(df.info())
    
    display("\nПервые 5 строк датафрейма:")
    display(df.head())
    
    display("\nОписание численных столбцов:")
    display(df.describe())
    
    display("\nКоличество явных дубликатов в датасете:")
    display(df.duplicated().sum())

    display("\nКоличество пропущенных значений в датасете:")
    display(df.isna().sum())
    
    display("\nЧастота распределений для категориальных столбцов:")
    for column in df.select_dtypes(include=['object', 'category']).columns:
        display(f"\nСтолбец '{column}':")
        display(df[column].value_counts())

# %%
def data_loss(df, df_raw, column_name='name'):
    # Абсолютные потери
    loss_absolute = df_raw[column_name].count() - df[column_name].count()

    # Относительный показатель
    loss_relative = 100 - (df[column_name].count() / df_raw[column_name].count() * 100)
    loss_relative = round(loss_relative, 2)

    # Преобразование в строку и добавление символа '%'
    loss_relative = str(loss_relative) + '%'

    display(f'Абсолютный показатель потери данных в столбце {column_name}: {loss_absolute}')
    display(f'Относительный показатель потери данных в столбце {column_name}: {loss_relative}')

# %%
def aggregate_weekly_data(df):
    
    aggregated_data = df.groupby(['date', 'category']).agg(
        purchases=('order_id', 'nunique'), 
        sales=('sales', 'sum')
    ).reset_index()
    
    aggregated_data['week'] = aggregated_data['date'].dt.to_period('W').apply(lambda r: r.start_time)
    
    weekly_data = aggregated_data.groupby(['week', 'category']).sum().reset_index()
    
    return weekly_data

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Здорово, что используешь собственные функции. Это действительно удобно и практично.
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# В предобработке данных мы подготовим данные для дальнейшего анализа.

# %% [markdown]
# ### Знакомоство с данными

# %% [markdown]
# Для начала загрузим данные.

# %%
try:
    df = pd.read_csv('/datasets/ecom_dataset_upd.csv')
except:
    df = pd.read_csv('https://code.s3.yandex.net/datasets/ecom_dataset_upd.csv')

# %%
# введем также переменную для расчета показателя потери данных
try:
    df_raw = pd.read_csv('/datasets/ecom_dataset_upd.csv')
except:
    df_raw = pd.read_csv('https://code.s3.yandex.net/datasets/ecom_dataset_upd.csv')

# %% [markdown]
# Познакомимся с основными хараткеристиками данных с помощью функции primary_analysis()

# %% [markdown]
# Сразу введем новый столбец - продажи, где перемножим цену с количеством проданных товаров. Эту переменную мы будем использовать для анализа выбросов по чеку покупки

# %%
df['sales'] = df['quantity'] * df['price']

# %%
primary_analysis(df)
# Out:
# 'Информация о датафрейме:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   int64
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
#  6   sales        7474 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 408.9+ KB
# None
# '\nПервые 5 строк датафрейма:'
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✏️ Рекомендация тимлида: </b>
#
# Чтобы представление было более читаемым и аккуратным, рекомендую использовать display(), а не print(). Это сделает вывод датафрейма более наглядным.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил

# %% [markdown]
# В исследовании участвуют данные о 7474 транзакциях интернет-магазина. На первый взгляд, датафрейм не содержит строк с пропущенными значениями. Наименование колонок проведено правильно.
#
# Столбец date содержит 7474 непустых значений в формате int64. Однако, учитывая специфику данных, рекомендуется преобразовать его в формат datetime64. Это изменение будет внесено на следующем этапе исследования.
#
# Искать выбросы в quantity и price обрезать было некорректно. Мы так просто теряем самые дорогие товары из анализа и больше покупки. Выбросы стоит смотреть по чеку покупк. Их границу рассчитываются по межквартильному размаху (1.5 * IQR). Работа с аномальными значениями будет продолжена в следующих главах предобработки данных.
#
# Полные дубликаты в датасете отсутствуют, но нельзя исключить наличие частичных или явных дубликатов. Этот вопрос будет рассмотрен на следующих этапах предобработки данных.
#
# Что касается категориальных столбцов, уже на данном этапе можно сделать несколько интересных наблюдений, которые будут детально разобраны в исследовательском анализе данных. Например:
#
# - Покупки топ-5 клиентов составляют 18.5% от всех транзакций интернет-магазина. Особенно выделяется клиент с customer_id 1d6c8c1f-a799-4418-9af2-1ded47d7a85c, на которого приходится почти 12% всех покупок.
# - В топ-5 товаров входят 4 наименования различных рассад, из которых 3 — рассады кабачков разных сортов.
#
# В остальном данные нормальны. Возьмем эти наблюдения и перейдем к преобработке данных, где мы:
#
# - Взглянем подробнее на пропуски
# - Помеянем типы данных на нужные
# - Проанализруем глубже тему дубликатов
# - Обработаем выбросы
# - Добавим колонку с категориями товаров
# - Оценим потерю данных, если придется удалять строки из датафрейма

# %% [markdown]
# ### Пропущенные значения

# %% [markdown]
# Поверхностный контроль методом df.isna().sum() показал, что в данных пропусков нет. Описание численных и категориальных столбцов нам также подтверждает тот факт, что пробелы в данных отсутсвуют. Предпримем последнюю попытку - иногда пропуски обозначаются специальными символами, например, "N/A", "NULL", "NA", и так далее. Давайте проверим, встречаются ли такие строки в нашем наборе данных.

# %%
df[df.isin(['N/A', 'NA', 'null', 'NULL', 'none', 'None'])].sum()
# Out:
# date           0.0
# customer_id      0
# order_id       0.0
# product          0
# quantity       0.0
# price          0.0
# sales          0.0
# dtype: object

# %% [markdown]
# Таких значений нет, значит мы располагать всей полнотой информации.

# %% [markdown]
# ### Cоответствие типов

# %% [markdown]
# Изменим тип данных столбца date из int64 в datetime64.

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d%H')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   datetime64[ns]
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
#  6   sales        7474 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 408.9+ KB

# %%
df.head()
# Out:
#         date                           customer_id  order_id  \
# 0 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4 2018-10-01  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  sales
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0  112.0

# %% [markdown]
# Все остальные типы данных на своих местах, поэтому мы можем двигаться дальше.

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Если судить по анализу выше, то можно утверждать, что в данных отсутсвуют полные дубликаты. Однако давайте взглянем есть ли неполные дубликаты - попробуем найти близнецов по полям 'customer_id', 'order_id', 'product'.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Да, без колонки `date` можно проверить систему логирования.
#
#
# </div>

# %%
df[df.duplicated(subset=['customer_id', 'order_id', 'product'], keep='first')].head(60)
# Out:
#                    date                           customer_id  order_id  \
# 58  2018-10-02 18:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 59  2018-10-02 19:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 60  2018-10-02 20:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 63  2018-10-03 04:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 94  2018-10-04 13:00:00  32de7df8-8d4f-4c84-a7b9-c41d00dd83ba     68522
# 126 2018-10-07 17:00:00  ce0e0c29-8c8b-4714-84bd-80957224d4cf     68557
# 147 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 148 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 149 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 150 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 152 2018-10-09 06:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 153 2018-10-09 06:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# ...

# %% [markdown]
# Можно найти интересную закономерность - клиент с id ffaeab76-3a8d-49ee-860f-17273b2fc8a2 в разное время покупал один и тот же таз, однако order_id был присвоен один и тот же. Явно здесь присутсвует какая-то ошибка - можно предположить, что при добавлении новой товарной позиции старая может дублироваться. Этот факт подтверждает не только то, что совпадает order_id, но и тот факт, что совпадает количество наименований и их цена. Удалим повторяющиеся строки.

# %%
df = df.drop_duplicates(subset=['order_id', 'customer_id', 'product'])

# %%
data_loss(df, df_raw, column_name='date')
# Out:
# 'Абсолютный показатель потери данных в столбце date: 1886'
# 'Относительный показатель потери данных в столбце date: 25.23%'

# %% [markdown]
# Дубликаты транзакции составляли 25% от общего количества данных. Можем двигаться дальше - взглянем на выбросы.

# %% [markdown]
# ###  Выбросы и аномальные значения

# %% [markdown]
# Искать выбросы в quantity и price обрезать было некорректно. Мы так просто теряем самые дорогие товары из анализа и больше покупки. Выбросы стоит смотреть по чеку покупки. Их границу рассчитываются по межквартильному размаху (1.5 * IQR).

# %%
df['bill'] = df.groupby('order_id')['sales'].transform('sum')
df
# Out:
#                     date                           customer_id  order_id  \
# 0    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# ...                  ...                                   ...       ...
# 7469 2020-01-30 21:00:00  63208953-a8e4-4f77-9b47-3a46e7b72eee    104002
# 7470 2020-01-30 22:00:00  d99d25f1-4017-4fcd-8d29-c580cc695a1a    107336
# 7471 2020-01-31 02:00:00  2c9bd08d-8c55-4e7a-9bfb-8c56ba42c6d6    106336
# 7472 2020-01-31 12:00:00  cdd17932-623e-415f-a577-3b31312fd0e2    102002
# 7473 2020-01-31 15:00:00  2e460a26-35af-453d-a369-a036e95a40e0    103225
#
#                                                 product  quantity  price  \
# ...

# %%
unique_orders = df[['order_id', 'bill']].drop_duplicates()
unique_orders
# Out:
#       order_id    bill
# 0        68477  1037.0
# 7        68479   824.0
# 8        68478   269.0
# 9        68480   674.0
# 10       68483   820.0
# ...        ...     ...
# 7469    104002    76.0
# 7470    107336   869.0
# 7471    106336   354.0
# 7472    102002   128.0
# 7473    103225   104.0
#
# [3521 rows x 2 columns]

# %%
min_val = unique_orders['bill'].min()
q1 = unique_orders['bill'].quantile(0.25)
median = unique_orders['bill'].mean()
q3 = unique_orders['bill'].quantile(0.75)
max_val = unique_orders['bill'].max()

# %% [markdown]
# <div id="div_id15" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v3] : </b>
#
# <s>[⬆ Ошибка №15](#3)
#
# Будь пожалуйста внимательнее. Ты формируешь стастику по датафрейму где одна строка = товарной позиции. У тебя показатели среднего чека дублируются
#
# ![image.png](attachment:image.png)
#
# Это искажает расчет процентилей.
#
# Корректный расчет будет по таблице, где одна строка = один заказ
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Тороплюсь. Понял, в чем ошибка. Поправил. Надеюсь, что сейчас правильно.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v4] : </b>
#
# 👍
#
# </div>

# %%
iqr = q3 - q1
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

# %%
display(f"Минимальное значение (min): {min_val}")
display(f"25-й перцентиль (Q1): {q1}")
display(f"Медиана (50%): {median}")
display(f"75-й перцентиль (Q3): {q3}")
display(f"Максимальное значение (max): {max_val}")
display(f"IQR: {iqr}")
display(f"Нижняя граница выбросов: {lower}")
display(f"Верхняя граница выбросов: {upper}")
# Out:
# 'Минимальное значение (min): 9.0'
# '25-й перцентиль (Q1): 194.0'
# 'Медиана (50%): 1317.0336315440688'
# '75-й перцентиль (Q3): 1274.0'
# 'Максимальное значение (max): 675000.0'
# 'IQR: 1080.0'
# 'Нижняя граница выбросов: -1426.0'
# 'Верхняя граница выбросов: 2894.0'

# %% [markdown]
# Обработаем выбросы в столбце bill - уберем значения по нижней и верхней границе выбросов

# %%
unique_orders[unique_orders['bill'] >= upper].sort_values(by='bill')
# Out:
#       order_id      bill
# 2308     70718    2915.0
# 3195     14698    2922.0
# 346      68709    2923.0
# 5852     71965    2924.0
# 1349     69569    2924.0
# ...        ...       ...
# 1299     69504   32718.0
# 1022     69156   33680.0
# 1518     69830   47385.0
# 5071     71668   49432.0
# 5456     71743  675000.0
#
# [300 rows x 2 columns]

# %%
df[df['order_id'].isin([71668, 71743])]
# Out:
#                     date                           customer_id  order_id  \
# 5071 2019-06-11 07:00:00  146cd9bf-a95c-4afb-915b-5f6684b17444     71668
# 5456 2019-06-18 15:00:00  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6     71743
#
#                                                 product  quantity  price  \
# 5071   Вешалки мягкие для деликатных вещей 3 шт шоколад       334  148.0
# 5456  Вантуз с деревянной ручкой d14 см красный, Bur...      1000  675.0
#
#          sales      bill
# 5071   49432.0   49432.0
# 5456  675000.0  675000.0

# %% [markdown]
# Все заказы, превышающие верхнюю границу для выбросов, выглядят нормальными — в основном, это крупные заказы, включающие несколько товарных наименований в значительном количестве. Примером может служить заказ с order_id 69156. Однако два крупнейших заказа содержат только один вид товара, но в необычно большом количестве: 334 вешалки и 1000 вантузов. Это крайне нетипично и даже аномально по сравнению с остальными покупками, поэтому их можно считать выбросами и исключить из датасета.

# %%
df = df[~df['order_id'].isin([71668, 71743])]

# %% [markdown]
# <div id="div_id16" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №16](#2)
#
# Посмотри пожалуйста на отсекаемые данные. Действительно ли там аномальные заказы? У нас очень мало данных - мы должны их беречь.
#
# IQR используется для выделения выбросов, но необходимо учитывать контекст данных.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Сделал по-другому. Надеюсь, что ход мыслей теперь верный.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v4] : </b>
#
# Да, процентили не панацея -  всегда надо смотреть на данные, которые собираешься отсекать
#
# </div>

# %% [markdown]
# <div id="div_id12" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №12](#2)
#
# Что это? Расчеты должны быть выполнены с помощью python
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Добавил

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# <div id="div_id1" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №1](#1)
#
#     Для quantity: поскольку IQR = 0, это означает, что почти все значения сосредоточены на одном уровне — 1
#
# А где расчеты?
#
# ---
#
#     Для price: выбросами считаются значения, превышающие 952. Максимум (14917) явно является выбросом.
#
# Обрезать по прайсу некорректно. Мы так просто теряем самые дорогие товары из анализа. Выбросы стоит смотреть по чеку покупки.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Добавил

# %% [markdown]
# <div id="div_id2" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №12](#2)
#
#     Обработаем выбросы в столбце quantity
#
# Ты работаешь с выбросами по другой колонке
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Убрал

# %% [markdown]
# <div id="div_id13" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №13](#2)
#
#
# Как я говорил ранее
#
#     Выбросы стоит смотреть по чеку покупки.
#
# `sales` - это не чек покупки.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Долго не доходило. Теперь понял.

# %% [markdown]
# <div id="div_id2" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №2](#1)
#
# Подставлять вручную данные - плохая практика.
#
#     df['quantity'] > 999
#
# Чтобы сделать свой проект устойчивым к изменениям и более профессиональным, рекомендую автоматизировать процесс подстановки данных. Это избавит от необходимости вручную обновлять их в будущем и сделает твой проект воспроизводимым.
#
# ---
#
# Пожалуйста, просмотри весь проект и внеси необходимые коррективы там, где это требуется.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил

# %% [markdown]
# Стоит еще проверить на наличие заказов совершенных более чем одним покупателем - такие заказы некорректны и их стоить удалить

# %%
order_multiple_customers = df.groupby('order_id')['customer_id'].nunique()
incorrect_oreder_id = order_multiple_customers[order_multiple_customers > 1].index
incorrect_oreder_id
# Out:
# Int64Index([14872, 68785, 69283, 69310, 69345, 69410, 69485, 69531, 69833,
#             70114, 70542, 70631, 70726, 70808, 70903, 70946, 71054, 71226,
#             71461, 71480, 71542, 71571, 71648, 71663, 72188, 72778, 72790,
#             72845, 72950],
#            dtype='int64', name='order_id')

# %%
df = df[~df['order_id'].isin(incorrect_oreder_id)]

# %%
data_loss(df, df_raw, column_name='date')
# Out:
# 'Абсолютный показатель потери данных в столбце date: 1954'
# 'Относительный показатель потери данных в столбце date: 26.14%'

# %% [markdown]
# После всех макипуляций общая потеря данных составляет 26%

# %% [markdown]
# <div id="div_id3" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №3](#1)
#
# Стоит еще проверить на наличие заказов совершенных более чем одним покупателем. Такие заказы некорректны.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Добавил

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Добавление категории товаров

# %% [markdown]
# В этой главе добавим категории товаров с помощью очистки наименований и подоборка ключевых слов.

# %% [markdown]
# Начнем сподготовки данных:
#
# - Приведение текста к нижнему регистру.
# - Токенизация(представление в виде списка слов) или удаление путктуации/чисел/стоп-слов(частиц, союзов, предлогов)

# %%
df['product'] = df['product'].str.lower()

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
def preprocess_text(data, stopwords=stopwords.words("russian")):
    """Очистка текста и удаление стоп-слов"""
    text = re.sub('ё', 'e', data.lower())  
    text = re.sub(r"([,\.!?])", r" \1 ", text)  
    text = re.sub(r"[^а-яА-Я\s]+", "", text)  
    text = text.strip() 

    words = text.split()  
    removed_stopwords = [w for w in words if w in set(stopwords)]  
    cleaned_text = [w for w in words if w not in set(stopwords)] 

    print("Удалённые стоп-слова:", removed_stopwords)  
    
    return ' '.join([w for w in cleaned_text if len(w) >= 4])

# %%
df['product'] = df['product'].apply(preprocess_text)
# Out:
# Удалённые стоп-слова: ['в']
# Удалённые стоп-слова: ['в']
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: ['для']
# Удалённые стоп-слова: ['с']
# Удалённые стоп-слова: ['для', 'из']
# Удалённые стоп-слова: ['для', 'с']
# Удалённые стоп-слова: ['для']
# Удалённые стоп-слова: ['для']
# Удалённые стоп-слова: ['с']
# Удалённые стоп-слова: []
# Удалённые стоп-слова: ['с']
# Удалённые стоп-слова: ['с']
# Удалённые стоп-слова: ['для']
# Удалённые стоп-слова: ['для']
# Удалённые стоп-слова: []
# Удалённые стоп-слова: ['для', 'из']
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: ['для', 'по']
# Удалённые стоп-слова: ['для', 'в']
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: ['в']
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# Удалённые стоп-слова: []
# ...

# %%
def lemmatization_text(data, morph):
    """Приведение слов к нормальной форме"""
    result = ' '.join([morph.parse(x)[0].normal_form for x in data.split()])
    result = ' '.join([x for x in result.split() if x not in ['желтый',
                                                              'жёлтый',
                                                              'белый', 
                                                              'белая', 
                                                              'purple',
                                                              'фиолетовый',
                                                              'зеленый', 
                                                              'коралловая', 
                                                              'голубой',
                                                              'серая', 
                                                              'черная', 
                                                              'синяя', 
                                                              'вайт', 
                                                              'синий',
                                                              'объём',
                                                              'крышка',
                                                              'цвет',
                                                              'грузоподъёмность',
                                                              'кассета',
                                                              'диам',
                                                              'горшок',
                                                              'сорт',
                                                              'махровый',
                                                              'полумахровый',
                                                              'сиреневый',
                                                              'малиновый',
                                                              'розовый',
                                                              'красный',
                                                              'ампельный',
                                                              'пластмассовый',
                                                              'пластиковый',
                                                              'махровый',
                                                              'кухня',
                                                              'растение',
                                                              'комната',
                                                              'россия',
                                                              'кг',
                                                              'шт',
                                                              'смотреть',
                                                              'ванная'
                                                              'ажурный'
                                                              'хозяйственный']])
    return result

# %%
df['product'] = df['product'].apply(lambda x: lemmatization_text(x, morph))

# %% [markdown]
# После изучения очищенных наименований можно выделить 6 категорий:
# - Цветы
# - Овощи и фрукты
# - Садовые принадлежности
# - Текстиль и декор
# - Хозяйственные товары
# - Кухонная утварь
#
# Для каждой категории подберем ключевые слова, по которым каждое наименование будет категоризировано:

# %%
categories = { 
    'Цветы': [
        'радермахер', 'хризолидокарпус лутесценс', 'циперус зумул', 'шеффлера лузеана', 'хлорофитум',
        'цикламен', 'глоксиния', 'азалия индик биколор', 'гортензия микс', 'хризантема космо микс', 
        'мирт', 'бегония', 'адиантум лиза', 'каланхий каландив', 'антуриум', 'фиалка', 'гербер', 
        'душица', 'лаванда', 'аспарагус', 'афеляндр', 'сантолина', 'иссол лекарственный', 'артифемизия',
        'пеларгония', 'петуния', 'калибрахоа', 'роза', 'эвкалипт', 'кампанула', 'колокольчик карпатский', 
        'хризантема', 'бальзамин', 'фаленопсис', 'дендробиум', 'калла', 'георгин', 'гортензия',
        'настурция орхидный пламя', 'гвоздик', 'шалфей', 'тюльпан', 'незабудка', 'флокс', 
        'алиссума', 'пуансеттия', 'вербена', 'соланум', 'спатифиллум', 'мединилла магнифика', 
        'виола', 'крассула', 'фиттония', 'примула', 'бархатцы', 'подсолнечник', 'годеция', 
        'эшшольция', 'анемон', 'камнеломка', 'георгин', 'астр альпийский', 'змееголовник', 
        'импатиенс', 'цинерария', 'камнеломка', 'лантан', 'аквилегия', 'вероника', 'вербейник', 
        'рудбекия', 'бадан', 'гаилардиа', 'монарда', 'завёртка', 'клён', 'нивянник ромашка', 
        'овсянница', 'гаилардиа крупноцветковый', 'рудбекия тайгера', 'вероника колосковый', 
        'камнеломка тенистый', 'солидаго', 'фикус', 'капроновый', 'хоста', 'сциндапсус', 
        'фиксатор', 'калатея микс', 'мимоза стыдливый', 'замиокулькас', 'диффенбахий камилла', 
        'фуксия', 'камнеломка тенистый', 'антуриум', 'мирт', 'гортензия', 'тюльпан', 'осина', 
        'нефролепис бостон', 'гиацинт луковица', 'гиацинт', 'платикодон', 'петуния', 
        'девичий виноград', 'декабрист', 'физостегия вергинский', 'папоротник', 'монарда гибридный', 
        'вербейник монетчатый', 'котовник', 'лилейникнуть', 'папоротник страусникнуть', 
        'смолёвка звёздный взрыв', 'астр альпийский микс', 'камнеломка арендс', 'буддлей', 
        'георгин', 'эпипремнум ауреум', 'алансон','комнатный','юкка нитчатый','многолетний тимьянчабрец',
        'эхеверие перл нюрнберг','нолин цветной керамик','аптения','новогодний дерево сербский',
        'пуансеттие','полка ньюйорк правый белыйголуба','бакоп','бакоп мегакрупный','базилик овощной арарат',
        'колокольчик персиколистный','лобелия', 'лобелия регатта микс','однолетний табак душистый',
        'карниз ванная виогод раздвижной кольцо','эхеверие микс','тимьян','чабёр','зверобой продырявить оптимист',
        'базилик пурпурный звезда','базилик смесь зелёный','гардения','кофе арабика','алоэ вера',
        'календула бронзовый красавица','полка белыйчрный','шеффлера голд капелла','фатсия японский',
        'эхинокактус грузонь','полка токио чрный','цинния ацтек бургунди биколор',
        'цинния хаага мехико','круглый водолей', 'суккулента микс', 'кориандр', 'круглый', 'иссоп лекарственный', 
        'набор свереть дерево','молодило микс', 'мелисса лекарственный', 'розмарин', 'альбук спиралиса фризлсизлый', 
        'артемизия полынь горький', 'петлястрела рыбинск','калоцефалус брауни крашеный осенний микс', 
        'каллуна гарден герлс трехцветной', 'капсикума сальса оранжевый', 'настурция драгоценность вишневорозовый', 'календула пинк сюрпрайза', 'кореопсис толл',
        'лапчатка огненный пламя', 'гиностемма укоренить черенок', 'канадский коник нидерланды', 'кипарисовик лавсон элвудить нидерланды', 'новогодний дерево канадский коник', 'новогодний дерево канадский коник ведёрко',
        'петлить рояльный оксид', 'скиммия японский рубелла', 'розмарин', 'полка лондон', 'овощ мясо', 'петлить рояльный цинк',
        'азалия индик', 'полка берлин чрный', 'кодонант укоренить черенок', 'гимнокалициум микс', 'калатея крокат', 'полка мадрид белыйчрный штука штука',
        'крокус луковица', 'седума почвопокровный смесь окраска', 'азалия индик', 'карниз ванная алюминий хром', 'полка барселона', 'тортница',
        'базилик зелёный тонус', 'лавр', 'эхинацея микс', 'ясколка войлочный', 'розмарин', 'базилик зелёный тонус',
        'энотера миссурийский золотой', 'урнапепельница стать хоббик', 'цитрофортунелла кумквата штамбовый', 'пеперомия', 'календула суприма', 'цинния коралловый красавица',
        'цинния оранжевый король', 'базилик застольный', 'настурция лунный свет', 'однолетний астр', 'мускари луковица', 'однолетний тагетис мелкоцветковый',
        'однолетний циния', 'муррайя', 'кореопсис золотой маяк', 'однолетний портулак', 'однолетний газаний', 'базилик зелёный тонус',
        'кориандр стимул раннеспелый штука', 'однолетний циния', 'однолетний целозия метельчатый', 'джункус пенсила грасс', 'драцена фрагранс компакт', 'однолетний львиный',
        'однолетний сальвия', 'седума почвопокровный смесь окраска', 'хост микс', 'однолетний астр', 'однолетний циния', 'гайлардия крупноцветковый желтокрасный',
        'кореопсис золотой маяк', 'монард гибридный бергамо', 'однолетний астр', 'однолетний циния', 'полка мадрид белыйчрный штука штука', 'обувница квадро венга',
        'лапчатка травянистый', 'седума очиток видный', 'барвинок', 'молодило', 'пряный трава микс', 'бузульник пржевальский кленолистный',
        'седума почвопокровный смесь окраска', 'ясколка войлочный', 'лапчатка травянистый', 'небесный лазурь', 'ясколка войлочный', 'фатсия',
        'однолетний львиный', 'лавр нобилиса', 'лаватер монт блан', 'ванна оцинковать магнитогорск', 'небесный лазурь', 'базилик овощной пурпурный звезда штука среднеспелый',
        'базилик овощной тонус штука среднеспелый', 'валериан лекарственный кардиол штука', 'лавр', 'любисток удалец штука', 'монард', 'табак бордовый штука',
        'табак курительный юбилейный новый штука среднеспелый', 'базилик зелёный тонус', 'лавр', 'хамедорей', 'полка берлин чрный', 'сахарница фарфоровый',
        'полка барселона', 'полка торонто', 'розмарин', 'амариллис темнокрасный луковица', 'стейк', 'полка торонто',
        'полка италия белыйсерый', 'круглый', 'базилик застольный', 'эхеверие лила чин', 'сахарница фарфоровый', 'зверобой продырявить',
        'пахир акватик мультистем', 'полка торонто', 'подушка ассортимент', 'полка италия белыйсерый', 'полка пекин белыйчрный', 'лавр',
        'полка италия белыйсерый', 'литопс микс', 'настурция драгоценность вишневорозовый', 'круглый', 'кипарисовик лавсон элвудить нидерланды', 'хамедорей',
        'муррайя', 'базилик застольный', 'калатея крокат', 'азалия индик', 'калатея крокат', 'цитрофортунелла кумквата штамбовый',
        'полка берлин чрный', 'кореопсис золотой маяк', 'полка лондон', 'гиностемма укоренить черенок', 'молодило', 'круглый',
        'энотера миссурийский золотой', 'иссоп лекарственный', 'базилик овощной пурпурный звезда штука среднеспелый', 'базилик овощной тонус штука среднеспелый', 'азалия индик', 'базилик овощной тонус штука среднеспелый'    
    ],
    'Овощи и фрукты': [
        'дыня', 'огурец', 'морковь', 'картофель', 'кабачок', 'баклажан', 'клубника', 
        'капуста', 'укроп', 'арбуз', 'томат', 'петрушка', 'сельдерей', 'горох', 'земляника', 
        'патиссон диск раннеспелый', 'патиссон оранжевый', 'салат рукол дикий', 'салат рукол сицилия', 
        'тыква крупноплодный лечебный', 'порей победитель', 'импатиенс гвинея микс', 'вигна', 
        'порей победитель', 'тыква', 'томат', 'патиссон', 'порей', 'морковь', 'баклажан'
    ],
    'Садовые принадлежности': [
        'сад', 'хранение', 'уборка', 'садовые принадлежности', 'секатор', 'лопата', 'грабли', 
        'опрыскиватель', 'рассада', 'почва', 'мульча', 'удобрение', 'практичный', 'долговечный', 
        'удобный', 'эффективный', 'сверлофреза', 'плечики', 'гаражный', 'крепёж', 'пружина', 
        'корыто', 'кашпо', 'скребок', 'тряпкодержатель', 'лопатка', 'инструменты', 'практичный', 
        'долговечный', 'удобный', 'эффективный', 'сверлофреза', 'садовые', 'сменный блок ролик', 
        'пьезозажигалка мультиискра', 'садовые принадлежности', 'секатор', 'инструменты', 
        'садовые принадлежности', 'гаражный', 'крепёж', 'секатор', 'сверлофреза', 'лопата', 
        'плечики', 'гаражный', 'удобрение', 'практичный', 'удобный', 'эффективный', 'лопата', 
        'удобный', 'практичный', 'гаражный', 'многофункциональный', 'удобный', 'удобрение', 
        'гаражный', 'практичный', 'практичный', 'удобный', 'эффективный', 'рассада', 
        'почва', 'удобрение', 'практичный', 'лопата', 'практичный', 'инструменты', 
        'удобный', 'секатор', 'удобный', 'удобрение', 'секатор', 'удобрение', 
        'лопата', 'эффективный', 'инструменты', 'практичный', 'секатор', 'удобный', 
        'удобный', 'удобрение', 'секатор', 'садовые принадлежности', 'опрыскиватель', 
        'практичный', 'сад', 'крепёж', 'практичный', 'лопата', 'лопата', 'удобный', 
        'удобный', 'удобрение', 'удобрение', 'лопата', 'лопата', 'практичный', 'удобрение', 
        'секатор', 'удобрение', 'удобрение', 'инструменты', 'удобрение', 'лопата', 
        'удобрение', 'лопата', 'садовые принадлежности', 'удобрение', 'удобрение', 
        'секатор', 'удобрение', 'удобрение', 'удобрение', 'лопата', 'удобрение', 'удобрение', 
        'удобрение', 'лопата', 'удобрение', 'удобрение', 'удобрение', 'лопата', 
        'удобрение', 'удобрение', 'удобрение', 'удобрение', 'лопата', 'удобрение'
    ],
    'Текстиль и декор': [
        'коврик', 'скатерть', 'плед', 'текстиль', 'хлопок', 'покрывало',
        'наволочка', 'шторы', 'декор', 'уют', 'мягкий', 'стеганый',
        'стильный', 'рисунок', 'красивый', 'оригинальный', 'ковровый', 'штора',
        'ковёр', 'ковр', "одеяло",'халат','полотенце','сушилка', 'бельё', 'потолочный', 'напольный', 'настенный', 
        'складывающийся', 'переносной', 'компактный', 'быстрая сушка',
        'место для сушки', 'стирка', 'хранилище', 'практичный', 'удобный', 
        'эффективный', 'стильный', 
        'стеллаж обувь светлый', 'стеллаж обувь венга','мятый','муляж', 'фрукты', 'овощи', 
        'полиуретан', 'искусственный', 'реалистичный',
        'декор', 'интерьер', 'выставочный', 'витрина', 'кулинария', 'обучение',
        'моделирование', 'декоративный', 'праздничный', 'стильный', 
        'искусственные фрукты', 'искусственные овощи'
    ],
    'Хозяйственные товары': [
        'сумка', 'тележка', 'мусор', 'контейнер', 'корзина', 'организация',
        'хранение', 'упаковка', 'ведро', 'многофункциональный',
        'удобный', 'практичный', 'уход', 'чистота', 'стильный', 'эффективный',
        'подставка', 'прищепка', 'швабра', 'крышка', 'пыль', 'способы',
        'средство', 'бензин', 'гладильный', 'щётка', 'щеткаутюжок', 'штанга', 
        'щеткасмётка', 'мыло', 'зубной паста', 'унитазный', 'перчатка', 
        'стремянка', 'бутылка', 'стяжка', 'крем', 'подрукавник', 'пилообразный', 
        'подрукавник', 'бидон', 'хлебница', 'миска варение алюминиевый', 
        'ведро', 'ящик почтовый металлический ушко навесный замок домик', 
        'туалет', 'крем',"весы", "шуруповерт","сварка","плита","фоторамка", 'косметь',
        'кузьмич','сидение','вантуз','комод','ключница','ваза','складный детский пожарный машинка',
        'ножи','овальный','пластик','полимербыт','ручка','короб','смётка','паста',
        'тряпка','электрика','соль','штангенциркуль','пиретрум','насос','электрошнур',
        'пробка','кисточка','ополаскиватель','электроштопор','орехоколка','маска','ткань',
        'сверло','универсальный','ковш','лоток','лантан','шнур','батарейка','обувь','решётка',
        'кипятильник'
    ],
    'Кухонная утварь': [
        'кухонный', 'столовый', 'сталь', 'посуда', 'кухонные принадлежности',
        'кастрюли', 'сковородки', 'столовые приборы', 'сервировка',
        'утварь', 'принадлежности', 'аксессуары', 'гаджеты', 'дизайн',
        'практичность', 'удобство', 'минисковорода', 'сковорода', 'чайник', 
        'противень', 'овощеварка', 'тарелка', 'кружка', 'чехол', 
        'фужер', 'кувшин', 'банка', 'маслёнка', 'салатник', 'салфетка', 
        'салфетница', 'стакан', 'ложка', 'лопатка', 'толкушка', 'веник', 
        'гладильный', 'удобный', 'вешалка', 'крючок', 'чистка', 'прищепка', 
        'влажный', 'чистящий', 'светильник', 'стиральный', 'пена', 'пищевой', 
        'подголовник', 'угольник', 'линейка', 'крепёж', 'пружина', 'лестница',
        'строительный', 'губка', 'ножеточка', 'гладильный', 'щётка', 
        'щеткаутюжок', 'дорожный', 'хранилище', 'корыто', 'чистящее', 
        'антижир', 'банк', 'пластхозторг',
        'сотейник алюминиевый керамический покрытие керамика',
        'кастрюля эмалировать хозлэнд', 'кастрюля круглый серый чугунный',
        'термос стеклянный колба темнозелёный', 'соковыжималка цитрусовый',
        'термометр уличный оконный', 'тёрка', "набор чайный", "миксер", "утюг", "мясорубка", "кастрюля",
        "разделочная доска", "форма выпечки", "термос", "коробка", "кофр", "ящик",
        "упаковка","контейнер", "термометр", "мыльница", "венчик", "сито",'вилка','бокал',
        'форма','измельчитель','пресс чеснок','картофелемялка','сетка глажение',
        'совка','разделочный доска','чайный набор','блюдце','разделочный',
        'просеиватель','алюминиевый','нержавеющий','медь','полипропиленовый','керамика',
        'бульонница','нож','ёмкость','миска','блюдо','соковарка','скалка','отделитель'
    ]
}

# %%
def assign_category(description):
    for category, keywords in categories.items():
        if any(keyword in description for keyword in keywords):
            return category
    return 'Не определено'

# %%
df['category'] = df['product'].apply(assign_category)

# %% [markdown]
# Проверим как распределяются категории и есть ли товары с определенной категорией:

# %%
category_counts = df['category'].value_counts()

plt.figure(figsize=(16, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title('Количество товаров в каждой категории')
plt.xlabel('Категория')
plt.ylabel('Количество наименований')
plt.xticks(rotation=45)
plt.show()

uncategorized_items = df[df['category'] == 'Не определено']
display("Товары с категорией 'Не определено':")
display(uncategorized_items)
# Out:
# "Товары с категорией 'Не определено':"
# Empty DataFrame
# Columns: [date, customer_id, order_id, product, quantity, price, sales, bill, category]
# Index: []

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Согласен с логикой категоризации товаров
#
# </div>

# %%
uncategorized_items['product'].tolist()
# Out:
# []

# %% [markdown]
# Согласно графику, категоризация прошла успешно — товары без категории отсутствуют. Можно также отметить, что наибольшее количество покупок было осуществлено в категории «Цветы», где зафиксировано чуть больше 2000 транзакций. Следующими по популярности стали хозяйственные товары, текстиль и декор с 1000 транзакциями. Замыкают топ-категорий «Овощи и фрукты», «Кухонные принадлежности» и «Садовые принадлежности», каждая из которых набрала около 500 транзакций. В следующей части нашего исследования мы углубимся в анализ данных, чтобы лучше понять эти тенденции.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# В рамках исследовательского анализа проанализируем основные показатели интернет-магазина.

# %% [markdown]
# ### Анализ распределения покупок по категориям товаров

# %% [markdown]
# Подсчитаем общее количество покупок для каждой товарной категории и используем столбчатую диаграмму для наглядного сравнения количества покупок по категориям.

# %% [markdown]
# Для начала введем словарь цветов, чтобы категории имели один и тот же цвет на протяжении всего проекта.

# %%
category_colors = {
    'Цветы': '#4CAF50',
    'Хозяйственные товары': '#303F9F',
    'Текстиль и декор': '#FFD54F',
    'Овощи и фрукты': '#E64A19',
    'Кухонная утварь': '#ff0ecf',
    'Садовые принадлежности': '#9C27B0'
}

# %%
category_counts = df['category'].value_counts().reset_index()
category_counts.columns = ['category', 'count']
category_counts
# Out:
#                  category  count
# 0                   Цветы   2240
# 1    Хозяйственные товары   1009
# 2        Текстиль и декор    968
# 3          Овощи и фрукты    564
# 4         Кухонная утварь    499
# 5  Садовые принадлежности    240

# %%
colors = [category_colors[category] for category in category_counts['category']]

fig, axs = plt.subplots(figsize=(14, 8))
sns.set_palette('pastel')
sns.set_style('white')
sns.barplot(x='category', y='count', data=category_counts, ax=axs, palette=colors)

axs.set_title("Распределение товаров по категории", fontsize=16)
axs.set_xlabel("Категории товаров", fontsize=14)
axs.set_ylabel("Количество товаров в категории", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✏️ Рекомендация тимлида: </b>
#
# Хочется обратить внимание на использование цвета в графике. В текущем исполнении цвет не добавляет дополнительного смысла к данным и может отвлекать от основной информации.
#
# Предлагаю пересмотреть использование цвета и применить его только в случае, если это помогает донести какую-либо важную информацию или улучшает интерпретацию графика.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Цель была присвоить каждой категории опреденный цвет и вести его через все исследование. Чуть-чуть поменял палитру, но цветастость графика оставил

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# <div id="div_id4" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №4](#1)
#
#     Распределение заведений по категории
#
#     Категории заведений
#
#     Количество заведений в категории
#
# Каких заведений? В датасете нет информации по заведениям.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# Наибольшее количество покупок было осуществлено в категории «Цветы», где зафиксировано чуть 2256 транзакций. Следующими по популярности стали хозяйственные товары, текстиль и декор с 1017 и 997 транзакциями соответсвенно. Замыкают топ-категорий «Овощи и фрукты», «Кухонные принадлежности» с 564 и 512 транзакциями. Категория с самым меньшим количеством покупок это "Садовые принадлежности" с 240 транзакциями.

# %% [markdown]
# ### Cезонность для категорий товаров

# %% [markdown]
# Исследуем, как изменяется количество покупок и выручка для разных категорий товаров в зависимости от времени. Попробуем визуазирировать с помощью линейного графика

# %% [markdown]
# Сгруппируем данные по дате и применим агрегирующие функции, которые помогут нам при построении графиков

# %%
aggregated_data = df.groupby(['date', 'category']).agg(
    purchases=('order_id', 'nunique'), 
    sales=('sales', 'sum') ).reset_index()

# %% [markdown]
# Группируем данные по неделям и пересчитываем количество покупок по категориям и неделям

# %%
aggregated_data['week'] = aggregated_data['date'].dt.to_period('W').apply(lambda r: r.start_time)
weekly_data = aggregated_data.groupby(['week', 'category']).sum().reset_index()

# %% [markdown]
# Наконец строим линейные графики.

# %%
plt.figure(figsize=(14, 8))

# График количества покупок
plt.subplot(2, 1, 1)
for category in weekly_data['category'].unique():
    category_data = weekly_data[weekly_data['category'] == category]
    plt.plot(category_data['week'], category_data['purchases'], label=category,color=category_colors[category])
plt.title('Количество покупок по категориям')
plt.xlabel('Дата')
plt.ylabel('Количество покупок')
plt.legend(loc='upper left')
plt.grid(True)

# График выручки
plt.subplot(2, 1, 2)
for category in weekly_data['category'].unique():
    category_data = weekly_data[weekly_data['category'] == category]
    plt.plot(category_data['week'], category_data['sales'], label=category,color=category_colors[category])
plt.title('Выручка по категориям')
plt.xlabel('Дата')
plt.ylabel('Выручка')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div id="div_id5" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №5](#1)
#
# 1. Количество покупок рассчитано неверно
#
#         aggregated_data = df.groupby(['date', 'category','customer_id']).agg(
#                                 purchases=('order_id', 'count'),
#                                 sales=('sales', 'sum') ).reset_index()
#
# Ты считаешь количество строк у каждого покупателя, а не уникальный `order_id`. Т.е. ты считаешь не количество order_id по категориям, а количество order_id у покупателя в разрезе категорий.
#
# ---
#
# 2. В покупках могут быть товары из разных категорий. При таком подходе покупка может быть отнесена к разным категориям, что искажает итоговый результат.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил код и вывод

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# Проанализируем графики для разных категорий:
#
# - Кухонная утварь: Количество покупок и выручка без выраженных пиков в определенные сезоны. Кухонные принадлежности приобретаются равномерно в течение года без сильной привязки к сезону.
#
# - Овощи и фрукты: Выручка и количество покупок резко поднимаются в марте и мае, что может быть связано с началом посадочных сезонов разных культур. Осенью (сентябрь-октябрь) также наблюдается рост, что может быть как-то связано с урожайным сезоном.
#
# - Садовые принадлежности: Очень выраженная сезонность - пиковые значения приходятся на весну (март-май), что логично, так как в это время начинается дачный сезон. Осенью также наблюдается небольшой рост, что также подводит к мысли о завершении дачного сезона и уборке территории, но он значительно меньше весеннего пика.
#
# - Текстиль и декор: Тенденция менее выраженная, но есть небольшие подъемы в зимний период (декабрь). Это может быть связано с тем, что текстиль и декор приобретаются для подготовки к праздничному сезону или как подарок к новогодним праздникам
#
# - Хозяйственные товары: Не имеют четко выраженной сезонности - также как и кухонная утварь эти товары нужны круглый год
#
# - Цветы: Четкий всплеск количества покупок и выручки в начале марта, что связано также связано с началом дачного сезона , а также небольшие подъемы в мае и сентябре, которые могут быть также связаны с посевами разных культур. Летом и осенью покупательская активность снижается.
#
# А теперь выделим конретные сезоны:
#
# - Март-май и сентябрь-октбярь: "Овощи и фрукты","Садовые принадлежности","Цветы"
# - Декабрь: "Текстиль и декор"

# %% [markdown]
# ### Анализ динамики общего среднего чека

# %% [markdown]
# Исследуем, как изменяется средний чек в зависимости от времени как общий так и для разных категорий товаров. Будем расчитывать через order_id по неделям. Для визуализации будем использовать линейный график.

# %% [markdown]
# Посчитаем общий средний чек

# %%
df['week'] = df['date'].dt.to_period('W').apply(lambda r: r.start_time)
overall_average_bill = df.groupby('week')['bill'].mean().reset_index()
overall_average_bill = overall_average_bill.rename(columns={'bill': 'average_bill'})

# %%
plt.figure(figsize=(14, 8))

# График динамики общего среднего чека
plt.plot(overall_average_bill['week'], overall_average_bill['average_bill'], label='Общий средний чек', color='orange')
plt.title('Общий средний чек')
plt.xlabel('Дата')
plt.ylabel('Средний чек')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div id="div_id6" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №6](#1)
#
# Здесь аналогично, средний чек рассчитан неверно. Далее я не буду акцентировать внимание на этом - перепроверь самостоятельно.
#
#     purchases=('order_id', 'count')
#
# ---
#
# В чеке могут быть товары из разных категорий
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил код выше и вывод

# %% [markdown]
# <div id="div_id14" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v2] : </b>
#
# <s>[⬆ Ошибка №14](#2)
#
#     В чеке могут быть товары из разных категорий
#
# Данное замечаение неотработано. В покупках (которые характеризуются средним чеком) могут быть товары из разных категорий. При твоем подходе покупка может быть отнесена к разным категориям, что искажает итоговый результат.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил код выше и вывод

# %% [markdown]
# <div id="div_id17" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида [v3] : </b>
#
# <s>[⬆ Ошибка №17](#3)
#
# Если в заказе могут быть товары из разных категорий, то как при расчете среднего чека ты их можешь отенсти к какой либо категории?
#
# Если в расчетах чека заказ одновременно в разных категориях, то это недостоверный результат получится. Поэтому предлагаю убрать данный расчет.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Теперь дошло. Убрал расчет - оставил только общий средний чек. Изменил вывод и поправил презентацию

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v4] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# Взглянем на общий средний чек:
#
#  - Средний чек демонстрирует значительные колебания, достигая пиков в начале и середине наблюдаемого периода. Эти колебания могут быть связаны c сезонность продаваемых товаров, например, "Овощи и фрукты","Цветы","Садовые принадлежности" в мае-июне 2019 года и рождественские и новогодние покупки в ноябре-декабре 2018 года.

# %% [markdown]
# ### Анализ выручки для категорий товаров и роста ее динамики

# %% [markdown]
# Исследуем, как изменяется общая выручка интернет-магазина в зависимости от времени - как общая, так идля разных категорий товаров. Для визализации используем кумулятивный график.

# %%
overall_sales = weekly_data.groupby('week')['sales'].sum().reset_index()
overall_sales['cumulative_sales'] = overall_sales['sales'].cumsum()
overall_sales
# Out:
#          week         sales  cumulative_sales
# 0  2018-10-01  82956.000000      8.295600e+04
# 1  2018-10-08  90489.000000      1.734450e+05
# 2  2018-10-15  68710.000000      2.421550e+05
# 3  2018-10-22  88058.000000      3.302130e+05
# 4  2018-10-29  73523.000000      4.037360e+05
# ..        ...           ...               ...
# 65 2019-12-30  51086.666667      3.716902e+06
# 66 2020-01-06  41755.500000      3.758657e+06
# 67 2020-01-13  45420.333333      3.804077e+06
# 68 2020-01-20  45733.000000      3.849810e+06
# 69 2020-01-27  15494.000000      3.865304e+06
#
# [70 rows x 3 columns]

# %%
plt.figure(figsize=(14, 8))

# График динамики роста общей кумулятивной выручки
plt.subplot(2, 1, 1)
plt.plot(overall_sales['week'], overall_sales['cumulative_sales'], label='Роста общей кумулятивной выручки', color='orange')
plt.title('Роста общей кумулятивной выручки')
plt.xlabel('Дата')
plt.ylabel('Кумулятивная выручка в миллионах')
plt.legend(loc='upper left')
plt.grid(True)

# График динамики роста кумулятивной выручки каждой категории
plt.subplot(2, 1, 2)
for category in weekly_data['category'].unique():
    category_data = weekly_data[weekly_data['category'] == category]
    plt.plot(category_data['week'], category_data['sales'].cumsum(), label=category,color=category_colors[category])
plt.title('Роста кумулятивной выручки каждой категории')
plt.xlabel('Дата')
plt.ylabel('Кумулятивная выручка в миллионах')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
overall_sales_category = weekly_data.pivot_table(index='category', values='sales', aggfunc='sum').fillna(0)

# %%
plt.figure(figsize=(14, 8))
colors = [category_colors[category] for category in overall_sales_category.index]
plt.pie(overall_sales_category['sales'], 
        labels=overall_sales_category.index, 
        autopct='%1.1f%%', 
        startangle=140,
        colors=colors
)
plt.title("Общая выручка по категориям (в процентах)")
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Очень хорошо, что следишь за цветовой схемой товарных категорий на визуализации
#
# </div>

# %% [markdown]
# Для начала рассмотрим общий рост кумулятивной выручки:
#
# - Наблюдается равномерный и линейный рост выручки, с увеличением на полмиллиона каждые два месяца. В конце анализируемого периода, на начало 2020 года, общий объем выручки достигает отметки в 4 миллиона рублей.
#
# Теперь рассмотрим динамику роста кумулятивной выручки по категориям:
#
# - Хозяйственные товары демонстрируют самый активный и стабильный (линейный) рост, увеличивая выручку на 250,000 рублей каждые два месяца. К концу периода выручка этой категории превышает 1,5 миллиона рублей, что составляет 42% от общей выручки.
# - Текстиль и декор также показывает устойчивый рост, хотя и менее выраженный по сравнению с "Хозяйственными товарами". В итоге выручка категории достигает 1 миллиона рублей, что составляет 27% от общего объема. Динамика этой категории характеризуется скачками в июне и январе, что коррелирует с изменениями среднего чека.
# - Цветы демонстрируют стабильный, но менее активный рост, немного не дотягивая до отметки в 750,000 рублей, что составляет 16% от общей выручки. В первой половине 2019 года темпы роста особенно высоки, однако к концу лета 2019 года рост замедляется, что может свидетельствовать о сезонном характере этой категории товаров.
# - Кухонная утварь достигает почти 500,000 рублей выручки, что составляет 10% от общей выручки. Основной рост приходится на первую половину 2019 года.
# - Садовые принадлежности показывают стабильный, но слабый рост, не достигая отметки в 100,000 рублей, что составляет 3% от общей выручки.
# - Овощи и фрукты закрывают список. Эта категория не приносит выручку до апреля 2019 года, после чего демонстрирует кратковременный рост до июля 2019 года, а затем выходит на плато, больше не генерируя значимых продаж. Доля этой категории в общей выручке составляет 2%, что также указывает на её сезонный характер.

# %% [markdown]
# ### Анализ помесячной динамики средней выручки с покупателя

# %% [markdown]
# В этой главе нам необходимо рассмотреть, как меняется средняя выручка на одного покупателя с теченим недель. Это позволит нам оценить лояльность покупателей и их активность в разные периоды. Для визуализации используем линейный график.

# %% [markdown]
# Для начала актуализируем переменную weekly_data - добавим customer_id и уберем category

# %%
aggregated_data = df.groupby(['date', 'category','customer_id']).agg(
    purchases=('order_id', 'count'), 
    sales=('sales', 'sum') ).reset_index()

# %%
aggregated_data['week'] = aggregated_data['date'].dt.to_period('W').apply(lambda r: r.start_time)

# %%
weekly_data = aggregated_data.groupby(['week','customer_id']).sum().reset_index()
weekly_data
# Out:
#            week                           customer_id  purchases   sales
# 0    2018-10-01  03b7b4a5-9e2c-42f9-a131-96f3d2772f17          1  1574.0
# 1    2018-10-01  0948b0c2-990b-4a11-b835-69ac4714b21d          1  3648.0
# 2    2018-10-01  161e1b98-45ba-4b4e-8236-e6e3e70f6f7c          1   820.0
# 3    2018-10-01  17213b88-1514-47a4-b8aa-ce51378ab34e          4  2374.0
# 4    2018-10-01  1bc8ad38-3392-4042-8cde-aa5de306c947         17   976.0
# ...         ...                                   ...        ...     ...
# 3229 2020-01-27  d6e08798-bdd5-45be-be79-843031be5b77          1    38.0
# 3230 2020-01-27  d99d25f1-4017-4fcd-8d29-c580cc695a1a          1   869.0
# 3231 2020-01-27  ea0d1348-249e-4aff-9149-599eb6d98dec          1    14.0
# 3232 2020-01-27  eeba9850-8d4b-40a7-a110-6d11a9196ddc          1    45.0
# 3233 2020-01-27  f19dee62-1f5a-4780-ac1d-8647b967207f          1    48.0
#
# [3234 rows x 4 columns]

# %% [markdown]
# Cгрупируем данные по неделям и по количеству уникальный пользователей.

# %%
weekly_customers = weekly_data.groupby('week')['customer_id'].nunique().reset_index(name='unique_customers')
weekly_customers
# Out:
#          week  unique_customers
# 0  2018-10-01                48
# 1  2018-10-08                48
# 2  2018-10-15                34
# 3  2018-10-22                43
# 4  2018-10-29                41
# ..        ...               ...
# 65 2019-12-30                70
# 66 2020-01-06                58
# 67 2020-01-13                72
# 68 2020-01-20                60
# 69 2020-01-27                29
#
# [70 rows x 2 columns]

# %% [markdown]
# Также сгрупируем данные по неделям, но теперь по общим продажам.

# %%
weekly_sales = weekly_data.groupby('week')['sales'].sum().reset_index()
weekly_sales
# Out:
#          week         sales
# 0  2018-10-01  82956.000000
# 1  2018-10-08  90489.000000
# 2  2018-10-15  68710.000000
# 3  2018-10-22  88058.000000
# 4  2018-10-29  73523.000000
# ..        ...           ...
# 65 2019-12-30  51086.666667
# 66 2020-01-06  41755.500000
# 67 2020-01-13  45420.333333
# 68 2020-01-20  45733.000000
# 69 2020-01-27  15494.000000
#
# [70 rows x 2 columns]

# %% [markdown]
# Соединим две таблицы.

# %%
weekly_summary = pd.merge(weekly_sales, weekly_customers, on='week')
weekly_summary['avg_sales_per_customer'] = weekly_summary['sales'] / weekly_summary['unique_customers']
weekly_summary
# Out:
#          week         sales  unique_customers  avg_sales_per_customer
# 0  2018-10-01  82956.000000                48             1728.250000
# 1  2018-10-08  90489.000000                48             1885.187500
# 2  2018-10-15  68710.000000                34             2020.882353
# 3  2018-10-22  88058.000000                43             2047.860465
# 4  2018-10-29  73523.000000                41             1793.243902
# ..        ...           ...               ...                     ...
# 65 2019-12-30  51086.666667                70              729.809524
# 66 2020-01-06  41755.500000                58              719.922414
# 67 2020-01-13  45420.333333                72              630.837963
# 68 2020-01-20  45733.000000                60              762.216667
# 69 2020-01-27  15494.000000                29              534.275862
#
# [70 rows x 4 columns]

# %% [markdown]
# Теперь построим линейный график средней выручки на одного покупателя по неделям.

# %%
plt.figure(figsize=(14, 8))
plt.plot(weekly_summary['week'], weekly_summary['avg_sales_per_customer'], color='orange', marker='o', linestyle='-')
plt.title("Средняя выручка на одного покупателя по неделям")
plt.xlabel("Неделя")
plt.ylabel("Средняя выручка на покупателя")
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Средняя выручка на покупателя рассчитана верно
#
# </div>

# %% [markdown]
# Проанализруем график:
#
# - Общая тенденция выглядит нисходящей, сопровождаясь колебаниями разной амплитуды. Период с ноября 2018 по февраль 2019 характеризуется значительными изменениями: значения снижаются до 1000 и поднимаются до 2500 в течение одного месяца. Подобные колебания также наблюдаются с апреля по июнь 2019 года. В дальнейшем амплитуда колебаний становится менее выраженной, но в октябре 2019 года происходит резкое падение до 500, и этот уровень удерживается до конца периода наблюдения. Причинами подобных колебаний могут быть праздники (Рождество и Новый год), сезонные факторы (начало садового сезона), а также влияние акционных кампаний.

# %% [markdown]
# ### Анализ частоты покупок

# %% [markdown]
# Анализ частоты покупок позволяет определить, как часто клиенты возвращаются за покупками. Лучшей визуализацией тут будет гистограмма

# %%
purchase_frequency = df.groupby('customer_id')['order_id'].nunique()
purchase_frequency.sort_values()
# Out:
# customer_id
# 000d6849-084e-4d9f-ac03-37174eaf60c4      1
# 9a06ca06-4fe8-4241-9e3c-b6252a2d30f0      1
# 99fd7fa2-4e47-4522-84b5-bd45176117c0      1
# 99e728ef-b118-477d-95a1-3dab449d2db1      1
# 9990ce3c-995c-4990-8dc5-75583a0c11d2      1
#                                        ...
# 0184f535-b60a-4914-a982-231e3f615206      5
# b7b865ab-0735-407f-8d0c-31f74d2806cc      7
# 73d1cd35-5e5f-4629-8cf2-3fda829d4e58     17
# 4d93d3f6-8b24-403b-a74b-f5173e40d7db     35
# c971fb21-d54c-4134-938f-16b62ee86d3b    126
# Name: order_id, Length: 2411, dtype: int64

# %% [markdown]
# <div id="div_id7" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание ревьюера : </b>
#
# <s>[⬆ Ошибка №7](#1)
#
# Это не частота покупок, а количество строк соответствующие данному покупателю. Покупка - это `order_id`
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил код выше и вывод

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %%
plt.figure(figsize=(14, 6))
plt.hist(purchase_frequency, bins=50, color='skyblue', edgecolor='black')
plt.title("Частота покупок клиентов")
plt.xlabel("Количество покупок")
plt.ylabel("Число клиентов")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
plt.boxplot(purchase_frequency, vert=False, patch_artist=True)
plt.title("Распределение частоты покупок клиентов")
plt.xlabel("Количество покупок")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Проанализруем график:
#
# - Распределение значений: Большинство значений сосредоточено около 1. Это может свидетельствовать о том, что большинство пользователей вовзаращились минимальное количество раз, например, 1-2 раза.
#
# - Аномальные показатели: Несмотря на преобладание низких значений, существует группа пользователей, которые возвращаются значительно чаще. В качестве примера можно привести пользователя с идентификатором c971fb21-d54c-4134-938f-16b62ee86d3b, который вернулся 126 раза. Это говорит о наличии лояльных клиентов или активных участников, которые активно покупают предлагаемые товары.

# %% [markdown]
# ## Основные вопросы исследования

# %% [markdown]
# В этой главе будем проводить сегментацию покупателей. Целью явялется создать 3 непохожих по поведению группы покупателей.

# %% [markdown]
# ### Сегментация покупателей с помощью RFM-анализа

# %% [markdown]
# Сегментация покупателей будет проведена с помощью метода RFM на основе историй их покупок. Будет выделено 3 группы покупателей - ушедшие клиенты, неактивные клиенты и постоянные клиенты. Метод будет выполнен с помощью фильтрации, создания вспомогательных столбцов и присвоения рангов.

# %% [markdown]
# Для начала определим последнюю дату транзакции

# %%
df['date'].sort_values()
# Out:
# 0      2018-10-01 00:00:00
# 1      2018-10-01 00:00:00
# 2      2018-10-01 00:00:00
# 3      2018-10-01 00:00:00
# 4      2018-10-01 00:00:00
#                ...
# 7469   2020-01-30 21:00:00
# 7470   2020-01-30 22:00:00
# 7471   2020-01-31 02:00:00
# 7472   2020-01-31 12:00:00
# 7473   2020-01-31 15:00:00
# Name: date, Length: 5520, dtype: datetime64[ns]

# %%
current_date = pd.to_datetime('2020-02-01')

# %% [markdown]
# Перегрупперуем данные на основе трех параметров, которые мы будем использовать для RFM анализа:
# - R(от англ. recency – давность) – определяет, как давно была совершена сделка. Показывает, сколько прошло времени с последней покупки. Для этого вычтем из current_date дату транзакции
# - F(от англ. frequency – частота) – показывает, насколько часто клиент покупает товар. Посчитаем при помоши функции count для столбца customer_id
# - M(от англ. monetary – деньги) – общая вложенность средств в продукт. Для этого используем функции sum к столбцу sales

# %%
df_rfm = df.groupby('customer_id').agg({
    'date': lambda x: (current_date - x.max()).days, 
    'customer_id': 'count',  
    'sales': 'sum'  
}).rename(columns={'date': 'recency', 'customer_id': 'frequency', 'sales': 'monetary'})

# %%
df_rfm
# Out:
#                                       recency  frequency  monetary
# customer_id
# 000d6849-084e-4d9f-ac03-37174eaf60c4      107          4     555.0
# 001cee7f-0b29-4716-b202-0042213ab038      349          1     442.0
# 00299f34-5385-4d13-9aea-c80b81658e1b      109          1     914.0
# 002d4d3a-4a59-406b-86ec-c3314357e498      369          1    1649.0
# 003bbd39-0000-41ff-b7f9-2ddaec152037      124          1    2324.0
# ...                                       ...        ...       ...
# ff601403-b094-4b86-9ac6-264d725b9277       12          2    1739.0
# ffaeab76-3a8d-49ee-860f-17273b2fc8a2       93          1     397.0
# ffb5976a-7a4d-460b-95c4-5ffaba31cb24      413          1     389.0
# ffb80538-3fda-4351-8ea9-9d2bec58bb07      144          1     974.0
# ffe82299-3f5b-4214-87fe-3d36ecccfac3      101          1     577.0
#
# [2411 rows x 3 columns]

# %% [markdown]
# Мы используем метод rank для присвоения рангов.

# %%
df_rfm['r_rank'] = df_rfm['recency'].rank(ascending=False, method='max').astype(int)
df_rfm['f_rank'] = df_rfm['frequency'].rank(ascending=True, method='min').astype(int)
df_rfm['m_rank'] = df_rfm['monetary'].rank(ascending=True, method='min').astype(int)

# %% [markdown]
# После ранжирования мы используем pd.cut, чтобы разбить значения рангов на 3 категории, чтобы они были от 0 до 2

# %%
df_rfm['r_rank'] = pd.cut(df_rfm['r_rank'], bins=3, labels=[1, 2, 3]).astype(int)
df_rfm['f_rank'] = pd.cut(df_rfm['f_rank'], bins=3, labels=[1, 2, 3]).astype(int)
df_rfm['m_rank'] = pd.cut(df_rfm['m_rank'], bins=3, labels=[1, 2, 3]).astype(int)

# %%
df_rfm
# Out:
#                                       recency  frequency  monetary  r_rank  \
# customer_id
# 000d6849-084e-4d9f-ac03-37174eaf60c4      107          4     555.0       2
# 001cee7f-0b29-4716-b202-0042213ab038      349          1     442.0       1
# 00299f34-5385-4d13-9aea-c80b81658e1b      109          1     914.0       2
# 002d4d3a-4a59-406b-86ec-c3314357e498      369          1    1649.0       1
# 003bbd39-0000-41ff-b7f9-2ddaec152037      124          1    2324.0       2
# ...                                       ...        ...       ...     ...
# ff601403-b094-4b86-9ac6-264d725b9277       12          2    1739.0       3
# ffaeab76-3a8d-49ee-860f-17273b2fc8a2       93          1     397.0       3
# ffb5976a-7a4d-460b-95c4-5ffaba31cb24      413          1     389.0       1
# ffb80538-3fda-4351-8ea9-9d2bec58bb07      144          1     974.0       2
# ffe82299-3f5b-4214-87fe-3d36ecccfac3      101          1     577.0       3
#
#                                       f_rank  m_rank
# ...

# %% [markdown]
# <div id="div_id8" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №8](#1)
#
# Раз уж ты реализуешь RFM сегментацию, то давай придерживаться стандартного кодирования 1-3, а не 0-2 как у тебя.
#
# Суть в том, что чем ценнее клиент, тем больше у него баллов. Например, ценность по RFM анализу еще могут характеризовать через RFM_score, который рассчитывается через весовые коэффициенты - можно считать, что один из показателей имеет большее влияние на поведение клиента, чем другие.
#
#         RFM Score = 0.15 * R + 0.28 * F + 0.57 * M
#
# И твой подход уже нельзя будет применить для подобного, т.к. твой способ кодирования содержит нули.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# Cложив все ранги получим общее значение RFM_Score.

# %%
df_rfm['rfm_score'] = 0.15 * df_rfm['r_rank'] + 0.28 * df_rfm['f_rank'] + 0.57 * df_rfm['m_rank']
df_rfm
# Out:
#                                       recency  frequency  monetary  r_rank  \
# customer_id
# 000d6849-084e-4d9f-ac03-37174eaf60c4      107          4     555.0       2
# 001cee7f-0b29-4716-b202-0042213ab038      349          1     442.0       1
# 00299f34-5385-4d13-9aea-c80b81658e1b      109          1     914.0       2
# 002d4d3a-4a59-406b-86ec-c3314357e498      369          1    1649.0       1
# 003bbd39-0000-41ff-b7f9-2ddaec152037      124          1    2324.0       2
# ...                                       ...        ...       ...     ...
# ff601403-b094-4b86-9ac6-264d725b9277       12          2    1739.0       3
# ffaeab76-3a8d-49ee-860f-17273b2fc8a2       93          1     397.0       3
# ffb5976a-7a4d-460b-95c4-5ffaba31cb24      413          1     389.0       1
# ffb80538-3fda-4351-8ea9-9d2bec58bb07      144          1     974.0       2
# ffe82299-3f5b-4214-87fe-3d36ecccfac3      101          1     577.0       3
#
# ...

# %% [markdown]
# Будем использовать распредление на ушедших, неактивных и постоянных клиентов на основе этого источника https://timeweb.com/ru/community/articles/chto-takoe-rfm-analiz

# %%
def segment_customer(score):
    if 2.5 < score <= 3:
        return 'Постоянные клиенты'
    elif 2 < score <= 2.5:
        return 'Неактивные клиенты'
    else:
        return 'Ушедшие клиенты'

# %%
df_rfm['rfm_segment'] = df_rfm['rfm_score'].apply(segment_customer)

# %%
df_rfm
# Out:
#                                       recency  frequency  monetary  r_rank  \
# customer_id
# 000d6849-084e-4d9f-ac03-37174eaf60c4      107          4     555.0       2
# 001cee7f-0b29-4716-b202-0042213ab038      349          1     442.0       1
# 00299f34-5385-4d13-9aea-c80b81658e1b      109          1     914.0       2
# 002d4d3a-4a59-406b-86ec-c3314357e498      369          1    1649.0       1
# 003bbd39-0000-41ff-b7f9-2ddaec152037      124          1    2324.0       2
# ...                                       ...        ...       ...     ...
# ff601403-b094-4b86-9ac6-264d725b9277       12          2    1739.0       3
# ffaeab76-3a8d-49ee-860f-17273b2fc8a2       93          1     397.0       3
# ffb5976a-7a4d-460b-95c4-5ffaba31cb24      413          1     389.0       1
# ffb80538-3fda-4351-8ea9-9d2bec58bb07      144          1     974.0       2
# ffe82299-3f5b-4214-87fe-3d36ecccfac3      101          1     577.0       3
#
# ...

# %% [markdown]
# Теперь перенесем информацию о сегментах из датасета df_rfm в основной датасет.

# %%
df_rfm.drop(columns=['recency', 'frequency','monetary','r_rank','f_rank','m_rank','rfm_score'], inplace=True)

# %%
df = df.merge(df_rfm[['rfm_segment']], on='customer_id', how='left')

# %%
df
# Out:
#                     date                           customer_id  order_id  \
# 0    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# ...                  ...                                   ...       ...
# 5515 2020-01-30 21:00:00  63208953-a8e4-4f77-9b47-3a46e7b72eee    104002
# 5516 2020-01-30 22:00:00  d99d25f1-4017-4fcd-8d29-c580cc695a1a    107336
# 5517 2020-01-31 02:00:00  2c9bd08d-8c55-4e7a-9bfb-8c56ba42c6d6    106336
# 5518 2020-01-31 12:00:00  cdd17932-623e-415f-a577-3b31312fd0e2    102002
# 5519 2020-01-31 15:00:00  2e460a26-35af-453d-a369-a036e95a40e0    103225
#
#                                                 product  quantity  price  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Сама по себе сегментация проведена корректно. Молодец!
#
# </div>

# %% [markdown]
# ### Описание полученных сегментов

# %% [markdown]
# Опишем и сравним размер сегментов, основыне товарные категории, средний чек, выручка, количество и частоту покупок, покупательскую лояльность (насколько часто они возвращаются за новыми покупками)

# %% [markdown]
# Для удобства также создадим словарь цветов

# %%
rfm_colors = {
    'Постоянные клиенты': '#77b41f',
    'Неактивные клиенты': '#101029',
    'Ушедшие клиенты': '#e34234',
}

# %% [markdown]
# #### Размеры сегментов

# %% [markdown]
# Начнем с размера сегментов.

# %%
rfm_counts = df.groupby('rfm_segment')['customer_id'].nunique().reset_index()
rfm_counts.columns = ['rfm_segment', 'count']
rfm_counts
# Out:
#           rfm_segment  count
# 0  Неактивные клиенты    724
# 1  Постоянные клиенты    457
# 2     Ушедшие клиенты   1230

# %%
colors = [rfm_colors[rfm_segment] for rfm_segment in rfm_counts['rfm_segment']]

fig, axs = plt.subplots(figsize=(18, 6))
sns.set_palette('pastel')
sns.set_style('white')
sns.barplot(x='rfm_segment', y='count', data=rfm_counts, ax=axs, palette=colors)

axs.set_title("Распределение клиентов по сегментам", fontsize=16)
axs.set_xlabel("Сегменты", fontsize=14)
axs.set_ylabel("Количество клиентов в сегметнах", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Больше всего ушедших клиентов - 1230
# - Дальше идут неактивные клиенты - 726
# - А также у нас есть и постоянных клиенты - их 456

# %% [markdown]
# #### Основные товарные категории

# %% [markdown]
# Теперь взглянем как располагаются категории товаров среди разных сегментов.

# %%
segment_category_df = df.pivot_table(index='rfm_segment', columns='category', values='order_id', aggfunc='count').fillna(0)
segment_category_df = segment_category_df.sort_values(by='Цветы', ascending=True)
segment_category_df
# Out:
# category            Кухонная утварь  Овощи и фрукты  Садовые принадлежности  \
# rfm_segment
# Ушедшие клиенты                 216              77                      60
# Неактивные клиенты              145             190                      66
# Постоянные клиенты              138             297                     114
#
# category            Текстиль и декор  Хозяйственные товары  Цветы
# rfm_segment
# Ушедшие клиенты                  359                   314    595
# Неактивные клиенты               301                   278    698
# Постоянные клиенты               308                   417    947

# %%
colors = [category_colors[category] for category in segment_category_df.columns]

sns.set_style('white')
sns.set_palette('pastel')

segment_category_df.plot(kind='barh', stacked=True, figsize=(18, 10), color=colors)

plt.title('Количество транзакций совершенных в ранзных категорий разными сегментами', fontsize=16)
plt.xlabel('Количество', fontsize=14)
plt.ylabel('Сегменты', fontsize=14)
plt.legend(title='Категория', fontsize=12)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.grid(axis='x', linestyle='--', alpha=0.7) 

plt.tight_layout()
plt.show()

# %% [markdown]
# - Ушедшие клиенты: Наибольшее количество транзакций приходится на категории "Цветы", "Текстиль и декор" и "Хозяйственные товары". Замыкает топ - "Кухонная утварь". Также в совсем небольшом количестве покупают товары из категории "Овощи и фрукты" и "Садовые принадлежности"
#
# - Неактивные клиенты: Эти клиенты также совершали много покупок в категориях "Цветы" и "Хозяйственные товары", но в других пропорицях - больше цветов и меньше хозяйственных товаров, также как и в категории "Текстиль и декор". Также большое количество товаров было приобртено из категории "Овощи и фрукты". Следом - "Кухонная утварь". Меньше всего - категория "Садовые принадлежности"
#
# - Постоянные клиенты: В целом можно сказать, что постоянные клиенты купили больше товаров - пропорции также копируют тренд ушедших клиентов и неактивных клиентов. Товаров в категории "Цветы" куплено гораздо больше, чем у остальных. Дальше примерно в равных долях идут хозяйственные товары, текстиль и декор, овощи и фрукты. Замыкают цепочку товары из категории "Кухонная утварь" и "Садовые принадлежности"
#
# Для повышения удержания и вовлеченности клиентов рекомендуется сосредоточить усилия на продвижении категорий "Цветы", "Текстиль и декор" и "Хозяйственные товары". Эти категории привлекают внимание как ушедших, так и неактивных клиентов, а также вызывают интерес у постоянных покупателей

# %% [markdown]
# #### Средний чек

# %% [markdown]
# Теперь взглянем на динамику среднего чека среди разных сегметов.

# %%
aggregated_data = df.groupby(['date', 'rfm_segment']).agg(
    purchases=('order_id', 'nunique'), 
    sales=('sales', 'sum') ).reset_index()
aggregated_data
# Out:
#                     date         rfm_segment  purchases   sales
# 0    2018-10-01 00:00:00  Неактивные клиенты          1  1037.0
# 1    2018-10-01 08:00:00     Ушедшие клиенты          2  1093.0
# 2    2018-10-01 09:00:00  Постоянные клиенты          1   674.0
# 3    2018-10-01 11:00:00     Ушедшие клиенты          1   820.0
# 4    2018-10-01 12:00:00  Неактивные клиенты          1   614.0
# ...                  ...                 ...        ...     ...
# 3128 2020-01-30 21:00:00  Неактивные клиенты          1    76.0
# 3129 2020-01-30 22:00:00  Постоянные клиенты          1   869.0
# 3130 2020-01-31 02:00:00  Неактивные клиенты          1   354.0
# 3131 2020-01-31 12:00:00  Неактивные клиенты          1   128.0
# 3132 2020-01-31 15:00:00     Ушедшие клиенты          1   104.0
#
# [3133 rows x 4 columns]

# %%
aggregated_data['week'] = aggregated_data['date'].dt.to_period('W').apply(lambda r: r.start_time)
aggregated_data
# Out:
#                     date         rfm_segment  purchases   sales       week
# 0    2018-10-01 00:00:00  Неактивные клиенты          1  1037.0 2018-10-01
# 1    2018-10-01 08:00:00     Ушедшие клиенты          2  1093.0 2018-10-01
# 2    2018-10-01 09:00:00  Постоянные клиенты          1   674.0 2018-10-01
# 3    2018-10-01 11:00:00     Ушедшие клиенты          1   820.0 2018-10-01
# 4    2018-10-01 12:00:00  Неактивные клиенты          1   614.0 2018-10-01
# ...                  ...                 ...        ...     ...        ...
# 3128 2020-01-30 21:00:00  Неактивные клиенты          1    76.0 2020-01-27
# 3129 2020-01-30 22:00:00  Постоянные клиенты          1   869.0 2020-01-27
# 3130 2020-01-31 02:00:00  Неактивные клиенты          1   354.0 2020-01-27
# 3131 2020-01-31 12:00:00  Неактивные клиенты          1   128.0 2020-01-27
# 3132 2020-01-31 15:00:00     Ушедшие клиенты          1   104.0 2020-01-27
#
# [3133 rows x 5 columns]

# %%
weekly_data = aggregated_data.groupby(['week', 'rfm_segment']).sum().reset_index()
weekly_data
# Out:
#           week         rfm_segment  purchases         sales
# 0   2018-10-01  Неактивные клиенты         20  34665.000000
# 1   2018-10-01  Постоянные клиенты         23  39849.000000
# 2   2018-10-01     Ушедшие клиенты         16   8442.000000
# 3   2018-10-08  Неактивные клиенты         16  38484.000000
# 4   2018-10-08  Постоянные клиенты         28  41497.000000
# ..         ...                 ...        ...           ...
# 205 2020-01-20  Постоянные клиенты         25  34638.833333
# 206 2020-01-20     Ушедшие клиенты         16   1465.666667
# 207 2020-01-27  Неактивные клиенты          7    951.000000
# 208 2020-01-27  Постоянные клиенты         11  13420.000000
# 209 2020-01-27     Ушедшие клиенты         11   1123.000000
#
# [210 rows x 4 columns]

# %%
weekly_data['average_bill'] = weekly_data['sales']/weekly_data['purchases']
weekly_data
# Out:
#           week         rfm_segment  purchases         sales  average_bill
# 0   2018-10-01  Неактивные клиенты         20  34665.000000   1733.250000
# 1   2018-10-01  Постоянные клиенты         23  39849.000000   1732.565217
# 2   2018-10-01     Ушедшие клиенты         16   8442.000000    527.625000
# 3   2018-10-08  Неактивные клиенты         16  38484.000000   2405.250000
# 4   2018-10-08  Постоянные клиенты         28  41497.000000   1482.035714
# ..         ...                 ...        ...           ...           ...
# 205 2020-01-20  Постоянные клиенты         25  34638.833333   1385.553333
# 206 2020-01-20     Ушедшие клиенты         16   1465.666667     91.604167
# 207 2020-01-27  Неактивные клиенты          7    951.000000    135.857143
# 208 2020-01-27  Постоянные клиенты         11  13420.000000   1220.000000
# 209 2020-01-27     Ушедшие клиенты         11   1123.000000    102.090909
#
# [210 rows x 5 columns]

# %%
plt.figure(figsize=(14, 8))

for rfm_segment in weekly_data['rfm_segment'].unique():
    rfm_segment_data = weekly_data[weekly_data['rfm_segment'] == rfm_segment]
    plt.plot(rfm_segment_data['week'], rfm_segment_data['average_bill'], label=rfm_segment, color=rfm_colors[rfm_segment])
plt.title('Динамика среднего чека для разнвых сегментов')
plt.xlabel('Дата')
plt.ylabel('Средний чек')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Постоянные клиенты в целом сохраняют более высокие значения среднего чека со временем, хотя и испытывают заметные колебания, особенно с пиком в начале 2019 года и еще одним ростом в середине 2019 года. После этих пиков средний чек стабилизируется, но остается ниже, чем ранее.
#
# - Ушедшие клиенты показывают стабиль низкий средний чек, который ко всему прочему имеет низходящую тенденцию
#
# - Неактивные клиенты демонстрируют значительные скачки в динамике среднего чека, что указывает на непостоянство этого сегмента. Эти колебания могут быть вызваны спонтанными покупками, связанными с акциями и скидками, а также изменениями в ассортименте и ценах, что говорит о том, что такие клиенты не имеют регулярного поведения и активно реагируют на временные предложения. Стоит также отметить, что значения среднего чека не уходят слишком далеко от значений постоянных клиентов, что говорит о важности этого сегмента.
#
# Постоянные клиенты обеспечивают наибольший доход, несмотря на колебания в среднем чеке, что делает их ценным сегментом для бизнеса. Ушедшие клиенты показывают снижение расходов перед полным оттоком, что может быть индикатором проблем. Неактивные клиенты имеют низкий средний чек, что указывает на необходимость целевых стратегий для их повторного вовлечения или на их меньшую ценность. В частности, постоянные клиенты демонстрируют более высокие значения среднего чека с заметными колебаниями, включая пики в начале и середине 2019 года. Ушедшие клиенты имеют стабильный низкий средний чек с понижательной тенденцией, тогда как неактивные клиенты проявляют значительные скачки, указывая на непостоянство их покупок, но при этом их средний чек близок к значениям постоянных клиентов, подчеркивая важность этого сегмента.

# %% [markdown]
# #### Выручка

# %% [markdown]
# В этом же духе взглянем на выручку.

# %%
plt.figure(figsize=(14, 8))

for rfm_segment in weekly_data['rfm_segment'].unique():
    rfm_segment_data = weekly_data[weekly_data['rfm_segment'] == rfm_segment]
    plt.plot(rfm_segment_data['week'], rfm_segment_data['sales'].cumsum(), label=rfm_segment,color=rfm_colors[rfm_segment])
plt.title('Роста кумулятивной выручки каждой сегмента')
plt.xlabel('Дата')
plt.ylabel('Кумулятивная выручка в миллионах')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Постоянные клиенты показывают стабильный рост кумулятивной выручки на протяжении всего периода, показывая прирост в 250000 каждые 2 месяца
#
# - Неактивные клиенты копируют тренд постоянных клиентов, однако их активность падаем после конца 2019 год и выходит практически на плато, что говорит нам о необходимости обратного вовлечения этого сегмента клиентов
#
# - Ушедшие имеют стабильную малую выручку до конца 2019 года, показывая прирост в 250000 каждые 6 месяцев. После этого периода этот сегмент снижает активность и выходит на плато.
#
# Постоянные клиенты демонстрируют устойчивый рост кумулятивной выручки на протяжении всего периода, с увеличением на 250000 каждые два месяца, что подтверждает их ценность для бизнеса. В то же время неактивные клиенты следуют аналогичному тренду, однако их активность начинает снижаться после конца 2019 года и стабилизируется на низком уровне, что подчеркивает необходимость стратегий по их повторному вовлечению. Ушедшие клиенты показывают стабильную низкую выручку до конца 2019 года с приростом на 250000 каждые шесть месяцев, но затем их активность также снижается и выходит на плато, указывая на необходимость внимания к причинам их оттока.

# %% [markdown]
# #### Количество и частота покупок

# %% [markdown]
# Взглянем на количество покупок в каждом сегменте

# %%
purchase_counts = df.groupby('rfm_segment')['order_id'].nunique().reset_index()
purchase_counts.columns = ['rfm_segment', 'purchase_count']
purchase_counts
# Out:
#           rfm_segment  purchase_count
# 0  Неактивные клиенты            1012
# 1  Постоянные клиенты            1024
# 2     Ушедшие клиенты            1454

# %%
colors = [rfm_colors[rfm_segment] for rfm_segment in rfm_counts['rfm_segment']]

fig, axs = plt.subplots(figsize=(18, 6))
sns.set_palette('pastel')
sns.set_style('white')
sns.barplot(x='rfm_segment', y='purchase_count', data=purchase_counts, ax=axs, palette=colors)

axs.set_title("Распределение транзакций по сегментам", fontsize=16)
axs.set_xlabel("Сегменты", fontsize=14)
axs.set_ylabel("Количество транзакций в сегметнах", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Самое большое количество покупок у ушедших клиентов - около 1400
# - У неактивных и постоянных клиентов число покупок одинаковое - 1000

# %% [markdown]
# Посчитаем частоту покупок для каждого сегмента

# %%
frequency_data = purchase_counts.merge(rfm_counts, on='rfm_segment')
frequency_data['purchase_frequency'] = frequency_data['purchase_count'] / frequency_data['count']
frequency_data
# Out:
#           rfm_segment  purchase_count  count  purchase_frequency
# 0  Неактивные клиенты            1012    724            1.397790
# 1  Постоянные клиенты            1024    457            2.240700
# 2     Ушедшие клиенты            1454   1230            1.182114

# %%
colors = [rfm_colors[rfm_segment] for rfm_segment in rfm_counts['rfm_segment']]

fig, axs = plt.subplots(figsize=(18, 6))
sns.set_palette('pastel')
sns.set_style('white')
sns.barplot(x='rfm_segment', y='purchase_frequency', data=frequency_data, ax=axs, palette=colors)

axs.set_title("Частота покупок по сегментам", fontsize=16)
axs.set_xlabel("Сегменты", fontsize=14)
axs.set_ylabel("Среднее количество покупок на одного клиента в каждом сегменте", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Что и следовало ожидать - самая большая частота покупок у постоянных клиентов клиентов - в среднем 2.3 покупки на одного клиента
# - Дальше идут ушедшие клиенты - в среднем 1.2 покупки на одного клиентач

# %% [markdown]
# #### Покупательская лояльность

# %% [markdown]
# Наконец взгялнем на лояльность разных сегментов. Выразим ее в с помощью Retention Rate.

# %%
df['first_purchase_date'] = df.groupby('customer_id')['date'].transform('min')

# %%
df['month'] = df['date'].dt.to_period('M')
df['first_purchase_month'] = df['first_purchase_date'].dt.to_period('M')
df['is_returning'] = df['month'] > df['first_purchase_month']

# %%
retention_rate = df[df['is_returning']].groupby('rfm_segment')['customer_id'].nunique()/df.groupby('rfm_segment')['customer_id'].nunique()
retention_rate = retention_rate.reset_index()
retention_rate.columns = ['rfm_segment', 'retention_rate']
retention_rate
# Out:
#           rfm_segment  retention_rate
# 0  Неактивные клиенты        0.360497
# 1  Постоянные клиенты        0.715536
# 2     Ушедшие клиенты        0.136585

# %% [markdown]
# Вывод подтверждает правильность разбивки на сегменты - у постоянных клиентов самый высокий Retention Rate. Их этой таблицы следуют два простых вывода:
# - Постоянные клиенты – это ключевой сегмент с высокой лояльностью, и важно продолжать поддерживать их активность.
# - Неактивные и Ушедшие клиенты имеют низкий коэффициент удержания, поэтому необходимо рассмотреть меры по их повторному вовлечению, если это возможно, или сосредоточиться на более активном удержании постоянных клиентов.

# %% [markdown]
# <div id="div_id9" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> НАПОМИНАНИЕ : </b>
#
# <s>В этом разделе все те же самые ошибки расчетов метрик, что я отметил ранее. Доработай, пожалуйста.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил код выше и все выводы

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Анализ категорий товаров и их сезонность по выделенным сегментам покупателей

# %% [markdown]
# Проанализируем характер покупок и поведение в рамках сегмента с точки зрения сезонности, если клиенты данного сегмента склонны совершать покупки во время сезонных акций

# %% [markdown]
# Рассмотрим 4 категории товаров, для которых была обнаружена сезонность - Цветы, Овощи и фрукты, Садовые принадлежности, Текстиль и Декор. Построим графики общих продаж и сравним с графиками продаж для разных сегментов.

# %%
df_lived_flowers_customers = df[(df['rfm_segment'] == 'Ушедшие клиенты') & (df['category'] == 'Цветы')]
df_regular_flowers_customers = df[(df['rfm_segment'] == 'Постоянные клиенты') & (df['category'] == 'Цветы')]
df_unactive_flowers_customers = df[(df['rfm_segment'] == 'Неактивные клиенты') & (df['category'] == 'Цветы')]
df_flowers_overall = df[(df['category'] == 'Цветы')]

# %%
weekly_data_flowers_lived = aggregate_weekly_data(df_lived_flowers_customers)
weekly_data_flowers_regular = aggregate_weekly_data(df_regular_flowers_customers)
weekly_data_flowers_unactive = aggregate_weekly_data(df_unactive_flowers_customers)
weekly_data_overall = aggregate_weekly_data(df_flowers_overall)

# %%
plt.figure(figsize=(14, 10))
plt.plot(weekly_data_overall['week'], 
         weekly_data_overall['purchases'], 
         label='Общие продажи Цветы',
         color='blue')
plt.plot(weekly_data_flowers_lived['week'], 
         weekly_data_flowers_lived['purchases'], 
         label='Продажи цветов для ушедших клиентов',
         color=rfm_colors['Ушедшие клиенты'])
plt.plot(weekly_data_flowers_regular['week'], 
         weekly_data_flowers_regular['purchases'], 
         label='Продажи цветов для постоянных клиентов',
         color=rfm_colors['Постоянные клиенты'])
plt.plot(weekly_data_flowers_unactive['week'], 
         weekly_data_flowers_unactive['purchases'], 
         label='Продажи цветов для неактивных клиентов',
         color=rfm_colors['Неактивные клиенты'])
plt.title('Количество покупок по категории "Цветы"')
plt.xlabel('Дата')
plt.ylabel('Количество покупок')
plt.legend(loc='upper left')
plt.grid(True)

# %% [markdown]
# Можно сказть, что ушедшие и неактивные клиенты покупают товары из категории "Цветы" в период сезонности этих товаров. Это значит, что эти сегменты можно нацелить на повторное вовлечение, чтобы увеличить их траты и, возможно, превратить их в постоянных клиентов.

# %%
df_lived_vegfrut_customers = df[(df['rfm_segment'] == 'Ушедшие клиенты') & (df['category'] == 'Овощи и фрукты')]
df_regular_vegfrut_customers = df[(df['rfm_segment'] == 'Постоянные клиенты') & (df['category'] == 'Овощи и фрукты')]
df_unactive_vegfrut_customers = df[(df['rfm_segment'] == 'Неактивные клиенты') & (df['category'] == 'Овощи и фрукты')]
df_vegfrut_overall = df[(df['category'] == 'Овощи и фрукты')]

# %%
weekly_data_vegfrut_lived = aggregate_weekly_data(df_lived_vegfrut_customers)
weekly_data_vegfrut_regular = aggregate_weekly_data(df_regular_vegfrut_customers)
weekly_data_vegfrut_unactive = aggregate_weekly_data(df_unactive_vegfrut_customers)
weekly_data_overall = aggregate_weekly_data(df_vegfrut_overall)

# %%
plt.figure(figsize=(14, 10))
plt.plot(weekly_data_overall['week'], 
         weekly_data_overall['purchases'], 
         label='Общие продажи Овощи и фрукты',
         color='blue')
plt.plot(weekly_data_vegfrut_lived['week'], 
         weekly_data_vegfrut_lived['purchases'], 
         label='Продажи Овощи и фрукты для ушедших клиентов',
         color=rfm_colors['Ушедшие клиенты'])
plt.plot(weekly_data_vegfrut_regular['week'], 
         weekly_data_vegfrut_regular['purchases'], 
         label='Продажи Овощи и фрукты для постоянных клиентов',
         color=rfm_colors['Постоянные клиенты'])
plt.plot(weekly_data_vegfrut_unactive['week'], 
         weekly_data_vegfrut_unactive['purchases'], 
         label='Продажи Овощи и фрукты для неактивных клиентов',
         color=rfm_colors['Неактивные клиенты'])
plt.title('Количество покупок по категории "Овощи и фрукты"')
plt.xlabel('Дата')
plt.ylabel('Количество покупок')
plt.legend(loc='upper left')
plt.grid(True)

# %% [markdown]
# Мы модем наблюдать идентичную ситуацию - неактивные и ушедшие клиенты совершали свои покупки в период сезонности категории "Овощи и фрукты". Постоянные пользователи не следовали сезонности. Опять же это говорит о эффективности таргетированной рекламы.

# %%
df_lived_garden_customers = df[(df['rfm_segment'] == 'Ушедшие клиенты') & (df['category'] == 'Садовые принадлежности')]
df_regular_garden_customers = df[(df['rfm_segment'] == 'Постоянные клиенты') & (df['category'] == 'Садовые принадлежности')]
df_unactive_garden_customers = df[(df['rfm_segment'] == 'Неактивные клиенты') & (df['category'] == 'Садовые принадлежности')]
df_garden_overall = df[(df['category'] == 'Садовые принадлежности')]

# %%
weekly_data_garden_lived = aggregate_weekly_data(df_lived_garden_customers)
weekly_data_garden_regular = aggregate_weekly_data(df_regular_garden_customers)
weekly_data_garden_unactive = aggregate_weekly_data(df_unactive_garden_customers)
weekly_data_overall = aggregate_weekly_data(df_garden_overall)

# %%
plt.figure(figsize=(14, 10))
plt.plot(weekly_data_overall['week'], 
         weekly_data_overall['purchases'], 
         label='Общие продажи Садовые принадлежности',
         color='blue')
plt.plot(weekly_data_garden_lived['week'], 
         weekly_data_garden_lived['purchases'], 
         label='Продажи Садовые принадлежности для ушедших клиентов',
         color=rfm_colors['Ушедшие клиенты'])
plt.plot(weekly_data_garden_regular['week'], 
         weekly_data_garden_regular['purchases'], 
         label='Продажи Садовые принадлежности для постоянных клиентов',
         color=rfm_colors['Постоянные клиенты'])
plt.plot(weekly_data_garden_unactive['week'], 
         weekly_data_garden_unactive['purchases'], 
         label='Продажи Садовые принадлежности для неактивных клиентов',
         color=rfm_colors['Неактивные клиенты'])
plt.title('Количество покупок по категории "Садовые принадлежности"')
plt.xlabel('Дата')
plt.ylabel('Количество покупок')
plt.legend(loc='upper left')
plt.grid(True)

# %% [markdown]
# Мы модем наблюдать идентичную ситуацию - неактивные и ушедшие клиенты совершали свои покупки в период сезонности категории "Садовые принадлежности". Постоянные пользователи не следовали сезонности. Опять же это говорит о эффективности таргетированной рекламы.

# %%
df_lived_textiles_customers = df[(df['rfm_segment'] == 'Ушедшие клиенты') & (df['category'] == 'Текстиль и декор')]
df_regular_textiles_customers = df[(df['rfm_segment'] == 'Постоянные клиенты') & (df['category'] == 'Текстиль и декор')]
df_unactive_textiles_customers = df[(df['rfm_segment'] == 'Неактивные клиенты') & (df['category'] == 'Текстиль и декор')]
df_textiles_overall = df[(df['category'] == 'Текстиль и декор')]

# %%
weekly_data_textiles_lived = aggregate_weekly_data(df_lived_textiles_customers)
weekly_data_textiles_regular = aggregate_weekly_data(df_regular_textiles_customers)
weekly_data_textiles_unactive = aggregate_weekly_data(df_unactive_textiles_customers)
weekly_data_overall = aggregate_weekly_data(df_textiles_overall)

# %%
plt.figure(figsize=(14, 10))
plt.plot(weekly_data_overall['week'], 
         weekly_data_overall['purchases'], 
         label='Общие продажи Текстиль и декор',
         color='blue')
plt.plot(weekly_data_textiles_lived['week'], 
         weekly_data_textiles_lived['purchases'], 
         label='Продажи Текстиль и декор для ушедших клиентов',
         color=rfm_colors['Ушедшие клиенты'])
plt.plot(weekly_data_textiles_regular['week'], 
         weekly_data_textiles_regular['purchases'], 
         label='Продажи Текстиль и декор для постоянных клиентов',
         color=rfm_colors['Постоянные клиенты'])
plt.plot(weekly_data_textiles_unactive['week'], 
         weekly_data_textiles_unactive['purchases'], 
         label='Продажи Текстиль и декор для неактивных клиентов',
         color=rfm_colors['Неактивные клиенты'])
plt.title('Количество покупок по категории "Текстиль и декор"')
plt.xlabel('Дата')
plt.ylabel('Количество покупок')
plt.legend(loc='upper left')
plt.grid(True)

# %% [markdown]
# <div id="div_id9" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №9](#1)
#
# Цвет общих продаж совпадает с цветом постоянных клиентов. Возникает путаница
#
# ![image.png](attachment:image.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил для всех графиков

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# 👍
#
# </div>

# %% [markdown]
# Нельзя точно сказать, что покупка разными сегментами товаров из категории "Текстиль и декор" отвечает сезонности этих товаров.

# %% [markdown]
# ### Выявление сегментов с высоким потенциалом для персонализированных предложений.

# %% [markdown]
# В ходе исследования были выделены три ключевых сегмента покупателей: постоянные клиенты, ушедшие клиенты и неактивные клиенты. Для каждого из этих сегментов можно предложить персонализированные маркетинговые стратегии.
#
# - Постоянные клиенты: Этот сегмент демонстрирует высокую лояльность и устойчивый средний чек. Рекомендуется использовать персонализированные рассылки и специальные предложения в категориях «Цветы», «Текстиль и декор» и «Хозяйственные товары», которые уже привлекают их внимание. Также стоит рассмотреть возможность внедрения программы лояльности для дальнейшего удержания.
#
# - Ушедшие клиенты: Этот сегмент проявляет интерес к товарам в категориях «Цветы», «Текстиль и декор» и «Кухонные принадлежности». Необходимо запустить таргетированные рекламные кампании с акцентом на сезонные предложения в этих категориях, чтобы вернуть клиентов. Рассмотрение возможности акций на товары, которые они покупали ранее, также может способствовать их повторному вовлечению.
#
# - Неактивные клиенты: Хотя они имеют самый низкий средний чек, их вовлечение возможно через специальные предложения и скидки на товары, которые ранее привлекали их внимание, такие как «Овощи и фрукты» и «Садовые принадлежности». Создание привлекательных акций и улучшение ассортимента в этих категориях могут помочь в увеличении их активности. Такде необходимо запустить таргетированные рекламные кампании с акцентом на сезонные предложения в этих категориях.
#
# Общая тенденция показывает, что неактивные и ушедшие клиенты часто покупают товары в периоды сезонного спроса. Это создает возможность для маркетинговых кампаний, нацеленных на повторное вовлечение этих клиентов. Важно сосредоточиться на персонализированных предложениях, которые могут вызвать интерес и вернуть клиентов, в то время как постоянные клиенты должны оставаться в центре внимания для дальнейшего роста и удержания.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Проверка статистических гипотез позволит оценить качество проведённой сегментации, поскольку она покажет, насколько значительно различается поведение пользователей в разных сегментах. Это поможет убедиться в том, что выделенные сегменты действительно отличаются друг от друга по ключевым характеристикам, что важно для дальнейшей персонализации предложений.

# %% [markdown]
# ### Выдвижение гипотез

# %% [markdown]
# - Нулевая гипотеза (H0): Средние чеки покупателей в разных сегментах одинаковы.
# - Альтернативная гипотеза (H1): Средние чеки хотя бы в одном из сегментов отличаются.

# %% [markdown]
# - Нулевая гипотеза (H0): Средняя частота покупок в разных сегментах одинаковая.
# - Альтернативная гипотеза (H1): Средняя частота покупок хотя бы в одном из сегментов отличается.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида  : </b>
#
# Очень хорошо, что не забываешь про формулировку гипотез. Это важный пункт в подобного рода задачах.
#
# </div>

# %% [markdown]
# ### Проверка статистических гипотез

# %% [markdown]
# Проверка гипотез будет проведена попарно - 1/2, 1/3, 2/3. Для проверки гипотез будем использовать t-test о равенстве средних двух генеральных совокупностей. Чтобы избежать ложноположительных результатов, нужно применять коррекцию для уровня значимости по Бонферрони.

# %%
alpha = 0.05

n_tests = 3 

alpha_bonferroni = alpha / n_tests

# %% [markdown]
# <div id="div_id10" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №10](#1)
#
# Не увидел поправку на множественную проверку гипотез. Ты просто сравниваешь с уровнем значимости 0.1
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid " ><b> Комментарий студента : </b>
#     Поправил

# %%
aggregated_data = df.groupby(['date', 'rfm_segment']).agg(
    purchases=('order_id', 'nunique'), 
    sales=('sales', 'sum') ).reset_index()

# %%
aggregated_data_rfm_segment = aggregated_data.groupby(['date', 'rfm_segment']).sum().reset_index()

# %%
aggregated_data_rfm_segment['average_bill'] = aggregated_data_rfm_segment['sales']/aggregated_data_rfm_segment['purchases']
aggregated_data_rfm_segment
# Out:
#                     date         rfm_segment  purchases   sales  average_bill
# 0    2018-10-01 00:00:00  Неактивные клиенты          1  1037.0        1037.0
# 1    2018-10-01 08:00:00     Ушедшие клиенты          2  1093.0         546.5
# 2    2018-10-01 09:00:00  Постоянные клиенты          1   674.0         674.0
# 3    2018-10-01 11:00:00     Ушедшие клиенты          1   820.0         820.0
# 4    2018-10-01 12:00:00  Неактивные клиенты          1   614.0         614.0
# ...                  ...                 ...        ...     ...           ...
# 3128 2020-01-30 21:00:00  Неактивные клиенты          1    76.0          76.0
# 3129 2020-01-30 22:00:00  Постоянные клиенты          1   869.0         869.0
# 3130 2020-01-31 02:00:00  Неактивные клиенты          1   354.0         354.0
# 3131 2020-01-31 12:00:00  Неактивные клиенты          1   128.0         128.0
# 3132 2020-01-31 15:00:00     Ушедшие клиенты          1   104.0         104.0
#
# [3133 rows x 5 columns]

# %%
segment_1 = aggregated_data_rfm_segment[aggregated_data_rfm_segment['rfm_segment'] == 'Постоянные клиенты']['average_bill']
segment_2 = aggregated_data_rfm_segment[aggregated_data_rfm_segment['rfm_segment'] == 'Ушедшие клиенты']['average_bill']
segment_3 = aggregated_data_rfm_segment[aggregated_data_rfm_segment['rfm_segment'] == 'Неактивные клиенты']['average_bill']

# Проведение t-теста для сегментов "Постоянные клиенты" и "Ушедшие клиенты"
results1 = stats.ttest_ind(segment_1, segment_2, alternative='greater')
display(f'Сравнение "Постоянные клиенты" и "Ушедшие клиенты" - p-value: {results1.pvalue:.4f}')
if results1.pvalue < alpha_bonferroni:
    display('Отвергаем нулевую гипотезу\n')
else:
    display('Нет оснований отвергнуть нулевую гипотезу\n')

# Проведение t-теста для сегментов "Постоянные клиенты" и "Неактивные клиенты"
results2 = stats.ttest_ind(segment_1, segment_3, alternative='greater')
display(f'Сравнение "Постоянные клиенты" и "Неактивные клиенты" - p-value: {results2.pvalue:.4f}')
if results2.pvalue < alpha_bonferroni:
    display('Отвергаем нулевую гипотезу\n')
else:
    display('Нет оснований отвергнуть нулевую гипотезу\n')

# Проведение t-теста для сегментов "Ушедшие клиенты" и "Неактивные клиенты"
results3 = stats.ttest_ind(segment_2, segment_3, alternative='greater')
display(f'Сравнение "Ушедшие клиенты" и "Неактивные клиенты" - p-value: {results3.pvalue:.4f}')
if results3.pvalue < alpha_bonferroni:
    display('Отвергаем нулевую гипотезу\n')
else:
    display('Нет оснований отвергнуть нулевую гипотезу\n')
# Out:
# 'Сравнение "Постоянные клиенты" и "Ушедшие клиенты" - p-value: 0.0000'
# 'Отвергаем нулевую гипотезу\n'
# 'Сравнение "Постоянные клиенты" и "Неактивные клиенты" - p-value: 0.0622'
# 'Нет оснований отвергнуть нулевую гипотезу\n'
# 'Сравнение "Ушедшие клиенты" и "Неактивные клиенты" - p-value: 1.0000'
# 'Нет оснований отвергнуть нулевую гипотезу\n'

# %%
purchase_frequency = df.groupby('customer_id')['order_id'].nunique().reset_index()
purchase_frequency.rename(columns={'order_id': 'purchase_frequency'}, inplace=True)
purchase_frequency
# Out:
#                                customer_id  purchase_frequency
# 0     000d6849-084e-4d9f-ac03-37174eaf60c4                   1
# 1     001cee7f-0b29-4716-b202-0042213ab038                   1
# 2     00299f34-5385-4d13-9aea-c80b81658e1b                   1
# 3     002d4d3a-4a59-406b-86ec-c3314357e498                   1
# 4     003bbd39-0000-41ff-b7f9-2ddaec152037                   1
# ...                                    ...                 ...
# 2406  ff601403-b094-4b86-9ac6-264d725b9277                   2
# 2407  ffaeab76-3a8d-49ee-860f-17273b2fc8a2                   1
# 2408  ffb5976a-7a4d-460b-95c4-5ffaba31cb24                   1
# 2409  ffb80538-3fda-4351-8ea9-9d2bec58bb07                   1
# 2410  ffe82299-3f5b-4214-87fe-3d36ecccfac3                   1
#
# [2411 rows x 2 columns]

# %%
df = pd.merge(df, purchase_frequency, on='customer_id')
df
# Out:
#                     date                           customer_id  order_id  \
# 0    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4    2018-10-01 00:00:00  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# ...                  ...                                   ...       ...
# 5515 2020-01-05 21:00:00  95872093-2887-4ce8-8468-19234990e7d7    103636
# 5516 2020-01-07 19:00:00  6921ac3e-bfcd-4a05-95d3-12ef81e874cc    111090
# 5517 2020-01-08 17:00:00  a843e87d-c9b8-475a-96fb-1edcccca5f8e    111091
# 5518 2020-01-23 00:00:00  a7ef9c85-57e1-45ad-89c9-8b405339d4c8    105757
# 5519 2020-01-29 11:00:00  9777b839-4212-41bb-94c2-87de3658248a    111436
#
#                                        product  quantity   price   sales  \
# ...

# %%
average_frequency_by_segment = df.groupby(['rfm_segment', 'date'])['purchase_frequency'].mean().reset_index()

# %%
average_frequency_by_segment
# Out:
#              rfm_segment                date  purchase_frequency
# 0     Неактивные клиенты 2018-10-01 00:00:00                 1.0
# 1     Неактивные клиенты 2018-10-01 12:00:00                 2.0
# 2     Неактивные клиенты 2018-10-01 15:00:00                 1.0
# 3     Неактивные клиенты 2018-10-01 21:00:00                 1.0
# 4     Неактивные клиенты 2018-10-02 11:00:00                 1.0
# ...                  ...                 ...                 ...
# 3128     Ушедшие клиенты 2020-01-28 14:00:00                 2.0
# 3129     Ушедшие клиенты 2020-01-28 15:00:00                 2.0
# 3130     Ушедшие клиенты 2020-01-29 11:00:00                 1.0
# 3131     Ушедшие клиенты 2020-01-30 08:00:00                 2.0
# 3132     Ушедшие клиенты 2020-01-31 15:00:00                 2.0
#
# [3133 rows x 3 columns]

# %%
segment_1 = average_frequency_by_segment[average_frequency_by_segment['rfm_segment'] == 'Постоянные клиенты']['purchase_frequency']
segment_2 = average_frequency_by_segment[average_frequency_by_segment['rfm_segment'] == 'Ушедшие клиенты']['purchase_frequency']
segment_3 = average_frequency_by_segment[average_frequency_by_segment['rfm_segment'] == 'Неактивные клиенты']['purchase_frequency']

# Проведение t-теста для средней частоты покупок между сегментами "Постоянные клиенты" и "Ушедшие клиенты"
results1_freq = stats.ttest_ind(segment_1, segment_2, alternative='greater')
display(f'Сравнение "Постоянные клиенты" и "Ушедшие клиенты" по частоте покупок - p-value: {results1_freq.pvalue:.4f}')
if results1_freq.pvalue < alpha_bonferroni:
    display('Отвергаем нулевую гипотезу\n')
else:
    display('Нет оснований отвергнуть нулевую гипотезу\n')

# Проведение t-теста для средней частоты покупок между сегментами "Постоянные клиенты" и "Неактивные клиенты"
results2_freq = stats.ttest_ind(segment_1, segment_3, alternative='greater')
display(f'Сравнение "Постоянные клиенты" и "Неактивные клиенты" по частоте покупок - p-value: {results2_freq.pvalue:.4f}')
if results2_freq.pvalue < alpha_bonferroni:
    display('Отвергаем нулевую гипотезу\n')
else:
    display('Нет оснований отвергнуть нулевую гипотезу\n')

# Проведение t-теста для средней частоты покупок между сегментами "Ушедшие клиенты" и "Неактивные клиенты"
results3_freq = stats.ttest_ind(segment_2, segment_3, alternative='greater')
display(f'Сравнение "Ушедшие клиенты" и "Неактивные клиенты" по частоте покупок - p-value: {results3_freq.pvalue:.4f}')
if results3_freq.pvalue < alpha_bonferroni:
    display('Отвергаем нулевую гипотезу\n')
else:
    display('Нет оснований отвергнуть нулевую гипотезу\n')
# Out:
# 'Сравнение "Постоянные клиенты" и "Ушедшие клиенты" по частоте покупок - p-value: 0.0000'
# 'Отвергаем нулевую гипотезу\n'
# 'Сравнение "Постоянные клиенты" и "Неактивные клиенты" по частоте покупок - p-value: 0.0000'
# 'Отвергаем нулевую гипотезу\n'
# 'Сравнение "Ушедшие клиенты" и "Неактивные клиенты" по частоте покупок - p-value: 1.0000'
# 'Нет оснований отвергнуть нулевую гипотезу\n'

# %% [markdown]
# В тестах сравнения Постоянные клиенты" и "Ушедшие клиенты" средних чеков и средней частоты покупок мы полпучили результат с отвержением нулевой гипотезы, то есть сущесвтует статически значимая разница между сегментами, что в свою очредь значит, что сегментация проведена верно.

# %% [markdown]
# ## Рекомендации

# %% [markdown]
# На основе результатов анализа мы предложим дальнейшие шаги для внедрения в бизнес-процессы.

# %% [markdown]
# ### Маркетинговая стратегия

# %% [markdown]
# В ходе исследования были выделены три ключевых сегмента покупателей: постоянные клиенты, ушедшие клиенты и неактивные клиенты. На основе RFM-сегментации и анализа покупательского поведения предлагается реализовать персонализированные маркетинговые кампании, направленные на каждый сегмент.
#
# - Постоянные клиенты: Для поддержки лояльности рекомендуется предлагать эксклюзивные скидки и бонусы за повторные покупки в особенности на товары категории "Текстиль и декор","Куханная утварь" и "Хозяйсвтенные товары", которые приносят больше всего вырчки и которые актуальны круглый год. Эксклюзивные скидки и бонусы повысят вырчку и увелчат лояльность этого сегмента
#
# - Неактивные и ушедшие клиенты: Эти клиенты подвержены влиянию сезонности, поэтому имеет смысл таргетировать их в определенные периоды:
#      - Когда: март, апрель, май, сентярь, октябрь
#      - Товарные категории: "Цветы","Овощи и фрукты","Cадовые приндалежности"
#      - Как: e-mail рассылка с рекламным предложением перед начало сезонности товара
#
# Общая тенденция показывает, что неактивные и ушедшие клиенты часто покупают товары в периоды сезонного спроса. Это создает возможность для маркетинговых кампаний, нацеленных на повторное вовлечение этих клиентов. Важно сосредоточиться на персонализированных предложениях, которые могут вызвать интерес и вернуть клиентов, в то время как постоянные клиенты должны оставаться в центре внимания для дальнейшего роста и удержания.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v2] : </b>
#
# Совсем другое дело
#
# </div>

# %% [markdown]
# <div id="div_id11" class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ⁉️ Критическое замечание тимлида : </b>
#
# <s>[⬆ Ошибка №11](#1)
#
# Рекомендации должны быть конкретными, чтобы заказчик на основе этой информации проработал рекламную рассылку товаров.
#
#
# **Каким клиентам (каким сегментам покупателей) когда (в какой месяц) какие категории товара рассылать в рекламных предложениях.**
#
#
# Это же была наша основная цель.
#
# </div>

# %% [markdown]
# ### Стратегия увеличения продаж

# %% [markdown]
# Поскольку наибольшую выручку и частоту покупок приносят товары из категорий «Цветы», «Текстиль и декор» и «Хозяйственные товары», стоит сосредоточиться на расширении ассортимента и внедрении акционных предложений в этих категориях.
#
# Для категорий с выраженной сезонностью (цветы, овощи и фрукты, садовые принадлежности) эффективны сезонные кампании. Внедрение акций, соответствующих сезонам (дачный и садовый сезон), привлечет дополнительных покупателей и увеличит продажи.

# %% [markdown]
# ### Стратегия увеличения лояльности

# %% [markdown]
# Постоянные клиенты являются ключевым источником выручки, и их удержание — приоритет. Внедрение программ лояльности с бонусами за частоту покупок и эксклюзивными скидками стимулирует их на более частые заказы.
#
# Для повышения возвращаемости ушедших клиентов полезно нацеливать их с помощью ретаргетинга и предложений на основе их предыдущих покупок, чтобы вернуть их внимание. Стоит уделить внимание на товары с выраженной сезонностью (речь идет и дачном и садовом сезоне). Необходимо конвертировать этих клиентов в паостоянных, чтобы потом удерживать с помощью разных программ лояльности.

# %% [markdown]
# ## Заключение и презентация

# %% [markdown]
# Мы провели исследование, подтвердив, что сегментация аудитории — эффективный инструмент для создания целевых маркетинговых стратегий, которые повышают продажи и укрепляют лояльность клиентов. Мы выделили три основные группы: постоянные, неактивные и ушедшие клиенты, и разработали уникальные подходы для повышения их активности. Для постоянных клиентов, как основного источника дохода, мы предложили программы лояльности и эксклюзивные скидки. Для неактивных и ушедших клиентов мы предложили сезонные акции и таргетированную рекламную кампанию с акцентом на интересующие их категории товаров. Применение этих рекомендаций поможет платформе «Пока всё ещё тут» увеличить выручку, повысить удовлетворенность клиентов и обеспечить долгосрочную устойчивость бизнеса.

# %% [markdown]
# Соберем осноновую информацию для отдела маркетинга в презентацию. Презентация будет включать три основных раздела:
# - Цели исследования
# - Результаты исследования
# - Рекомендации бизнесу
#
# v1: https://cloud.mail.ru/public/dCWs/pzusXQ6UB
# v2: https://cloud.mail.ru/public/sMMV/KNBfjBHE7 (изменение - общий средний чек)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid; position: relative; padding: 15px; padding-left: 80px;">
# <img src="https://lh3.googleusercontent.com/a/AAcHTtc31jlywy-FMYxLAouSSqNAmm5NsrBvivwRIASNt7wihI2ClYdpAbzWNqcigfcR04LfvopHwsJrJpnVr4UXDkCHtWk=s432-c-no" width="45" height="45" style="position: absolute; top: 15px; left: 15px; border-radius: 50%;">
# <b> ✔️ Комментарий тимлида [v3] : </b>
#
# Презентация выполнена качественно как по содержанию, так и по структуре. Все ключевые моменты исследования учтены. Предпочтение отдано тезисной подаче материала, текст на слайдах использован умеренно. Очень хорошо, что используешь инфографику.
#
# Тем не менее, было бы полезно добавить нумерацию слайдов для удобства при презентациях перед аудиторией.
#
# </div>
